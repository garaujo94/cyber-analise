# %% [markdown]
# ## Text Mining em documentos de Defesa Norte Americanos

# %% [markdown]
# ##### Objetivo:
# * Ver a quantidade de vezes que palavras relacionadas com cyber security aparecem aparecem conforme passam os anos.
#
# ##### Procedimento:
# 1. Ler cada documento deixando claro a que ano se refere
# 2. Remover pontuações e stopwords (lembrando de adicionar palavras como us, united, states)
# 3. Realizar a contagem de palavras
# 4. Plotar a evolução histórica dessa contagem

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from PyPDF2 import PdfFileReader
from bs4 import BeautifulSoup
import re
import string
import glob
import os
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud,STOPWORDS
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from collections import Counter

# %matplotlib inline

# %% [markdown]
# Criando função que lerá documentos

# %% [markdown]
# #### Em primeiro momento, será feita uma análise geral levando em conta todos os documentos de uma só vez. Após isso, será analisado cada documento separadamente

# %%
def ler_(arquivo): #Essa versão é a que está valendo
    pdf = open(arquivo, "rb")
    reader = PdfFileReader(pdf)
    tamanho = reader.numPages
    
    pages = []
    
    for i in range(tamanho):
        pages.append(reader.getPage(i).extractText())
        
    text = " ".join(pages)
    
    return text

# %%
textos = os.listdir('textos')

# %%
textos[0][:4]
# Out:
# '2006'

# %% [markdown]
# Lendo documentos e armazenando por ano num DataFrame

# %%
ano = []
text = []
for texto in textos:
    ano.append(texto[:4])
    text.append(ler_('textos/'+texto))
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %%
df = pd.DataFrame(text, columns=['text'], index=ano)

# %%
df.head()
# Out:
#                                                    text
# 2006        Annual Threat Assessment of the Director...
# 2007    \n Annual Threat Assessment \nof the \nDirec...
# 2008       Annual Threat Assessment of the   Intelli...
# 2009       Annual Threat Assessment of the   Intelli...
# 2010      Annual Threat Assessment of the   US Intel...

# %% [markdown]
# A arquivo do ano de 2011 é um pdf scaneado!

# %%
nltk.download('stopwords')
stop = stopwords.words('english')
#punctuation = list(string.punctuation)
#stop.update(punctuation)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Adicionando algumas palavras que se percebeu ser comum nos arquivos e que não somam muito no objetivo
stop.append('us')
stop.append('united')
stop.append('states')
stop.append('also')

# %% [markdown]
# #### Tirando caracteres especiais

# %%
alphanumeric = lambda x: re.sub(r"""\w*\d\w*""", ' ', x)
punc_lower = lambda x: re.sub('[%s]' % re.escape(string.punctuation), ' ', x.lower())
remove_br = lambda x: re.sub(r""" br """, ' ', x.lower())
remove_n = lambda x: re.sub(r""" [\r\n]+ """, ' ', x.lower())
line = lambda x: x.strip()
linen =  lambda x: re.sub("\n","",x)


df['text_b'] = df.text.map(alphanumeric).map(punc_lower).map(remove_br).map(remove_n).map(line).map(linen)
df['text_b'] = df['text_b'].apply((lambda x: re.sub('[^a-zA-z0-9\s]','',x)))

# %%
df
# Out:
#                                                    text  \
# 2006        Annual Threat Assessment of the Director...
# 2007    \n Annual Threat Assessment \nof the \nDirec...
# 2008       Annual Threat Assessment of the   Intelli...
# 2009       Annual Threat Assessment of the   Intelli...
# 2010      Annual Threat Assessment of the   US Intel...
# 2011
# 2012   \n \n \n \n \nUnclassified Statement for the ...
# 2013     Statement for the Record  \n Worldwide Thre...
# 2014   \n \n \nStatement for the Record \n \n \nWorl...
# 2015   \n \nStatement for the Record \n \n \nWorldwi...
# 2016   \nStatement for the Record \n \n \nWorldwide ...
# 2017   \n \nStatement for the Record \n \n \nWorldwi...
# 2018   \n1\n \n \n \n6 March 2018\n \n \n \n  \n2\n ...
# 2019     29 JANUARY\n 2019 Senate Select Committee o...
#
#                                                  text_b
# 2006  annual threat assessment of the director of na...
# 2007  annual threat assessment of the director of na...
# 2008  annual threat assessment of the   intelligence...
# 2009  annual threat assessment of the   intelligence...
# 2010  annual threat assessment of the   us intellige...
# 2011
# 2012  unclassified statement for the record on the  ...
# 2013  statement for the record  worldwide threat ass...
# 2014  statement for the record  worldwide threat ass...
# 2015  statement for the record  worldwide threat ass...
# 2016  statement for the record  worldwide threat ass...
# 2017  statement for the record  worldwide threat ass...
# 2018  march      statement for the record  worldwide...
# 2019  january   senate select committee on intellige...

# %% [markdown]
# Criando função que vai contabilizar as palavras no conjunto de arquivos

# %%
from sklearn.feature_extraction.text import CountVectorizer
def get_top_text_ngrams(corpus, g):
    vec = CountVectorizer(ngram_range=(g, g), stop_words=stop).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq

# %%
most_common_uni = get_top_text_ngrams(df.text_b,1)
most_common_uni = dict(most_common_uni)

# %%
plt.figure(figsize = (16,9))
sns.barplot(x=list(most_common_uni.values())[:30],y=list(most_common_uni.keys())[:30])
plt.show()

# %%
most_common_uni
# Out:
# {'security': 638,
#  'economic': 638,
#  'political': 539,
#  'continue': 514,
#  'government': 489,
#  'al': 424,
#  'military': 422,
#  'threat': 417,
#  'nuclear': 392,
#  'iran': 376,
#  'countries': 373,
#  'global': 370,
#  'attacks': 354,
#  'groups': 352,
#  'probably': 340,
#  'international': 325,
#  'intelligence': 311,
#  'weapons': 311,
#  'remain': 304,
#  'cyber': 300,
#  'support': 298,
#  'foreign': 298,
#  'likely': 294,
#  'russia': 291,
#  'year': 290,
#  'national': 285,
#  'new': 285,
#  'china': 277,
#  'interests': 275,
#  'forces': 274,
#  'north': 269,
#  'capabilities': 259,
#  'efforts': 256,
#  'terrorist': 247,
#  'regional': 246,
#  'iraq': 245,
#  'state': 244,
#  'including': 244,
#  'region': 244,
#  'oil': 243,
#  'influence': 238,
#  'assess': 234,
#  'threats': 231,
#  'use': 224,
#  'leaders': 222,
#  'since': 219,
#  'could': 219,
#  'syria': 217,
#  'operations': 216,
#  'however': 211,
#  'growth': 206,
#  'years': 204,
#  'power': 202,
#  'qaida': 201,
#  'violence': 201,
#  'many': 196,
#  'president': 195,
#  'conflict': 190,
#  'record': 190,
#  'statement': 186,
#  'east': 184,
#  'africa': 184,
#  'information': 183,
#  'challenges': 182,
#  'high': 182,
#  'percent': 181,
#  'potential': 179,
#  'energy': 177,
#  'pakistan': 176,
#  'south': 176,
#  'increase': 174,
#  'asia': 174,
#  'systems': 173,
#  'risk': 173,
#  'attack': 171,
#  'would': 170,
#  'growing': 168,
#  'continues': 166,
#  'central': 165,
#  'economy': 165,
#  'regime': 165,
#  'control': 164,
#  'major': 160,
#  'although': 160,
#  'increased': 158,
#  'afghanistan': 155,
#  'financial': 155,
#  'governments': 153,
#  'western': 152,
#  'significant': 152,
#  'korea': 151,
#  'key': 151,
#  'public': 149,
#  'world': 148,
#  'development': 147,
#  'russian': 147,
#  'areas': 146,
#  'elections': 146,
#  'policy': 145,
#  'remains': 143,
#  'increasingly': 143,
#  'ability': 142,
#  'past': 142,
#  'community': 141,
#  'among': 141,
#  'based': 140,
#  'may': 140,
#  'country': 138,
#  'last': 137,
#  'prices': 137,
#  'despite': 136,
#  'might': 136,
#  'networks': 135,
#  'long': 135,
#  'ata': 135,
#  'feb': 135,
#  'opposition': 134,
#  'human': 134,
#  'services': 133,
#  'term': 132,
#  'actors': 131,
#  'progress': 128,
#  'increasing': 128,
#  'missile': 128,
#  'water': 128,
#  'infrastructure': 127,
#  'production': 127,
#  'change': 124,
#  'two': 124,
#  'allies': 124,
#  'judge': 124,
#  'crisis': 124,
#  'space': 124,
#  'resources': 123,
#  'drug': 123,
#  'well': 122,
#  'violent': 122,
#  'india': 122,
#  'leadership': 121,
#  'domestic': 120,
#  'activities': 120,
#  'health': 119,
#  'food': 118,
#  'almost': 117,
#  'local': 117,
#  'iranian': 117,
#  'critical': 116,
#  'continued': 114,
#  'next': 114,
#  'access': 114,
#  'range': 113,
#  'even': 112,
#  'middle': 112,
#  'strategic': 111,
#  'sunni': 109,
#  'instability': 108,
#  'iraqi': 108,
#  'several': 108,
#  'europe': 107,
#  'corruption': 107,
#  'missiles': 107,
#  'ballistic': 105,
#  'force': 105,
#  'social': 104,
#  'group': 104,
#  'developing': 104,
#  'particularly': 103,
#  'capable': 103,
#  'stability': 103,
#  'relations': 103,
#  'tensions': 103,
#  'governance': 102,
#  'technology': 102,
#  'issues': 101,
#  'criminal': 101,
#  'still': 100,
#  'million': 100,
#  'technologies': 99,
#  'time': 99,
#  'trade': 99,
#  'election': 99,
#  'seek': 98,
#  'one': 97,
#  'irans': 97,
#  'number': 96,
#  'led': 96,
#  'face': 96,
#  'taliban': 96,
#  'provide': 96,
#  'law': 95,
#  'mass': 95,
#  'capability': 95,
#  'certainly': 94,
#  'climate': 94,
#  'democratic': 93,
#  'chinese': 93,
#  'extremists': 92,
#  'un': 92,
#  'develop': 92,
#  'moscow': 92,
#  'anti': 91,
#  'greater': 91,
#  'institutions': 91,
#  'west': 90,
#  'hizballah': 90,
#  'environment': 89,
#  'shia': 89,
#  'reforms': 89,
#  'crime': 89,
#  'armed': 89,
#  'challenge': 88,
#  'ethnic': 88,
#  'within': 87,
#  'pressure': 87,
#  'become': 85,
#  'america': 84,
#  'pose': 84,
#  'islamic': 84,
#  'coalition': 83,
#  'level': 83,
#  'expand': 83,
#  'policies': 83,
#  'population': 83,
#  'system': 82,
#  'low': 82,
#  'afghan': 81,
#  'transnational': 81,
#  'terrorists': 80,
#  'make': 79,
#  'toward': 79,
#  'made': 79,
#  'large': 78,
#  'tehran': 78,
#  'already': 78,
#  'sudan': 78,
#  'officials': 77,
#  'capacity': 77,
#  'program': 77,
#  'party': 77,
#  'activity': 77,
#  'isis': 77,
#  'future': 76,
#  'border': 76,
#  'chemical': 76,
#  'partners': 76,
#  'ongoing': 76,
#  'maintain': 76,
#  'sector': 76,
#  'assistance': 75,
#  'organizations': 75,
#  'threaten': 75,
#  'lead': 75,
#  'syrian': 75,
#  'levels': 75,
#  'trafficking': 75,
#  'targets': 74,
#  'used': 74,
#  'organized': 74,
#  'part': 74,
#  'problems': 74,
#  'humanitarian': 74,
#  'homeland': 73,
#  'important': 73,
#  'conduct': 73,
#  'especially': 73,
#  'european': 73,
#  'data': 73,
#  'wmd': 72,
#  'cooperation': 72,
#  'recent': 72,
#  'chinas': 72,
#  'internal': 71,
#  'addition': 70,
#  'emerging': 70,
#  'agreement': 70,
#  'opportunities': 69,
#  'insurgency': 69,
#  'worldwide': 69,
#  'arab': 69,
#  'improve': 69,
#  'presence': 69,
#  'ties': 69,
#  'members': 68,
#  'terrorism': 68,
#  'effective': 68,
#  'operational': 68,
#  'venezuela': 68,
#  'weak': 68,
#  'across': 68,
#  'eu': 68,
#  'defense': 67,
#  'regions': 66,
#  'nations': 66,
#  'lebanon': 66,
#  'difficult': 66,
#  'least': 66,
#  'somalia': 66,
#  'technical': 66,
#  'less': 65,
#  'elements': 65,
#  'limited': 65,
#  'late': 65,
#  'programs': 65,
#  'conditions': 65,
#  'presidential': 65,
#  'faces': 65,
#  'lack': 65,
#  'rising': 65,
#  'january': 65,
#  'first': 64,
#  'related': 64,
#  'need': 64,
#  'take': 64,
#  'markets': 64,
#  'people': 63,
#  'according': 63,
#  'role': 63,
#  'personnel': 63,
#  'concerned': 63,
#  'turkey': 63,
#  'economies': 63,
#  'proliferation': 62,
#  'individuals': 62,
#  'saudi': 62,
#  'rule': 62,
#  'concerns': 62,
#  'non': 62,
#  'beijing': 62,
#  'pursue': 62,
#  'means': 62,
#  'produce': 61,
#  'slow': 61,
#  'focus': 61,
#  'extremist': 61,
#  'strong': 61,
#  'december': 61,
#  'latin': 61,
#  'investment': 61,
#  'assessment': 60,
#  'see': 60,
#  'focused': 60,
#  'militants': 60,
#  'risks': 59,
#  'ukraine': 59,
#  'mexico': 59,
#  'additional': 59,
#  'following': 58,
#  'like': 58,
#  'three': 58,
#  'using': 58,
#  'small': 58,
#  'example': 58,
#  'beyond': 58,
#  'market': 58,
#  'minister': 58,
#  'advanced': 58,
#  'address': 58,
#  'result': 57,
#  'far': 57,
#  'impact': 57,
#  'materials': 57,
#  'internet': 57,
#  'isil': 57,
#  'include': 56,
#  'training': 56,
#  'lebanese': 56,
#  'natural': 56,
#  'target': 56,
#  'november': 56,
#  'yemen': 56,
#  'war': 55,
#  'demand': 55,
#  'providing': 55,
#  'israel': 55,
#  'popular': 55,
#  'confidence': 55,
#  'adversaries': 55,
#  'peace': 55,
#  'commercial': 55,
#  'rise': 54,
#  'abroad': 54,
#  'outside': 54,
#  'near': 54,
#  'reform': 54,
#  'democracy': 54,
#  'situation': 54,
#  'aid': 54,
#  'undermine': 54,
#  'nation': 53,
#  'goals': 53,
#  'pakistani': 53,
#  'militant': 53,
#  'conducted': 53,
#  'prime': 53,
#  'civil': 53,
#  'private': 53,
#  'movement': 52,
#  'scale': 52,
#  'sectarian': 52,
#  'coming': 52,
#  'continuing': 52,
#  'improving': 52,
#  'chavez': 52,
#  'african': 52,
#  'poor': 52,
#  'qaidas': 51,
#  'much': 51,
#  'network': 51,
#  'potentially': 51,
#  'committed': 51,
#  'uranium': 51,
#  'disease': 51,
#  'northern': 51,
#  'sustained': 51,
#  'counterterrorism': 50,
#  'counter': 50,
#  'conventional': 50,
#  'early': 50,
#  'effects': 50,
#  'often': 50,
#  'largest': 50,
#  'nigeria': 50,
#  'october': 50,
#  'supply': 49,
#  'build': 49,
#  'nato': 49,
#  'gain': 49,
#  'source': 49,
#  'hamas': 49,
#  'gas': 49,
#  'media': 49,
#  'events': 48,
#  'help': 48,
#  'american': 48,
#  'fighting': 48,
#  'persistent': 48,
#  'exploit': 48,
#  'perceived': 48,
#  'order': 48,
#  'prospects': 48,
#  'former': 48,
#  'rates': 48,
#  'unrest': 48,
#  'changes': 48,
#  'billion': 48,
#  'around': 47,
#  'muslim': 47,
#  'organization': 47,
#  'overseas': 47,
#  'process': 47,
#  'targeting': 47,
#  'along': 47,
#  'weapon': 47,
#  'unlikely': 47,
#  'end': 47,
#  'diplomatic': 47,
#  'migration': 47,
#  'gains': 47,
#  'espionage': 47,
#  'sanctions': 47,
#  'protests': 47,
#  'spread': 46,
#  'struggle': 46,
#  'enforcement': 46,
#  'march': 46,
#  'biological': 46,
#  'nearly': 46,
#  'developments': 46,
#  'decade': 46,
#  'objectives': 46,
#  'september': 45,
#  'achieve': 45,
#  'leader': 45,
#  'primary': 45,
#  'views': 45,
#  'external': 45,
#  'response': 45,
#  'reduce': 45,
#  'southern': 45,
#  'conflicts': 45,
#  'test': 45,
#  'fuel': 44,
#  'union': 44,
#  'trends': 44,
#  'five': 44,
#  'parties': 44,
#  'authority': 44,
#  'competition': 44,
#  'bilateral': 44,
#  'criminals': 44,
#  'illicit': 44,
#  'current': 44,
#  'kosovo': 44,
#  'sasc': 44,
#  'territory': 44,
#  'regimes': 43,
#  'senior': 43,
#  'enrichment': 43,
#  'army': 43,
#  'indian': 43,
#  'integration': 43,
#  'status': 43,
#  'publicly': 43,
#  'companies': 43,
#  'research': 42,
#  'disrupt': 42,
#  'core': 42,
#  'deal': 42,
#  'libya': 42,
#  'material': 42,
#  'work': 42,
#  'pursuing': 42,
#  'vulnerable': 42,
#  'measures': 42,
#  'expanding': 42,
#  'aqi': 42,
#  'fall': 42,
#  'decline': 42,
#  'view': 42,
#  'concern': 41,
#  'throughout': 41,
#  'fighters': 41,
#  'hold': 41,
#  'widespread': 41,
#  'expect': 41,
#  'asian': 41,
#  'direct': 41,
#  'effort': 41,
#  'service': 41,
#  'without': 41,
#  'engagement': 41,
#  'february': 40,
#  'july': 40,
#  'reach': 40,
#  'insurgents': 40,
#  'available': 40,
#  'threatening': 40,
#  'palestinian': 40,
#  'highly': 40,
#  'strike': 40,
#  'intent': 40,
#  'sea': 40,
#  'dangerous': 39,
#  'serious': 39,
#  'actions': 39,
#  'religious': 39,
#  'able': 39,
#  'developed': 39,
#  'overall': 39,
#  'create': 39,
#  'little': 39,
#  'korean': 39,
#  'crises': 39,
#  'largely': 39,
#  'nonstate': 39,
#  'months': 39,
#  'committee': 38,
#  'must': 38,
#  'protect': 38,
#  'majority': 38,
#  'second': 38,
#  'agenda': 38,
#  'eastern': 38,
#  'baghdad': 38,
#  'insurgent': 38,
#  'nevertheless': 38,
#  'seeks': 38,
#  'republic': 38,
#  'resistance': 38,
#  'significantly': 38,
#  'cuba': 38,
#  'citizens': 37,
#  'attempt': 37,
#  'success': 37,
#  'prevent': 37,
#  'home': 37,
#  'rights': 37,
#  'business': 37,
#  'substantial': 37,
#  'action': 37,
#  'given': 37,
#  'counterspace': 37,
#  'damage': 37,
#  'primarily': 37,
#  'funding': 37,
#  'gulf': 36,
#  'secure': 36,
#  'israeli': 36,
#  'strategy': 36,
#  'neighboring': 36,
#  'leading': 36,
#  'building': 36,
#  'territorial': 36,
#  'held': 36,
#  'making': 36,
#  'fragile': 36,
#  'revenue': 36,
#  'transition': 36,
#  'due': 36,
#  'per': 36,
#  'capital': 36,
#  'increases': 36,
#  'close': 36,
#  'parts': 36,
#  'plans': 36,
#  'talks': 36,
#  'refugees': 36,
#  'issue': 36,
#  'relationship': 35,
#  'know': 35,
#  'allied': 35,
#  'southeast': 35,
#  'seeking': 35,
#  'yet': 35,
#  'asad': 35,
#  'countrys': 35,
#  'advantage': 35,
#  'colombia': 35,
#  'relatively': 35,
#  'populations': 35,
#  'reduced': 35,
#  'pandemic': 35,
#  'associated': 35,
#  'plan': 35,
#  'online': 35,
#  'others': 34,
#  'jihadist': 34,
#  'advance': 34,
#  'top': 34,
#  'interest': 34,
#  'expanded': 34,
#  'aggressive': 34,
#  'try': 34,
#  'enable': 34,
#  'better': 34,
#  'dual': 34,
#  'eurasia': 34,
#  'exports': 34,
#  'sensitive': 34,
#  'offensive': 34,
#  'longer': 34,
#  'warfare': 34,
#  'facilities': 34,
#  'sophisticated': 34,
#  'air': 34,
#  'weather': 34,
#  'atrocities': 34,
#  'extremism': 33,
#  'responsible': 33,
#  'put': 33,
#  'destruction': 33,
#  'numerous': 33,
#  'taking': 33,
#  'delivery': 33,
#  'threatens': 33,
#  'rate': 33,
#  'drugs': 33,
#  'civilians': 33,
#  'campaign': 33,
#  'strengthen': 33,
#  'previously': 33,
#  'intended': 33,
#  'imf': 33,
#  'general': 32,
#  'communities': 32,
#  'stable': 32,
#  'tribal': 32,
#  'destabilizing': 32,
#  'acquire': 32,
#  'sectors': 32,
#  'soviet': 32,
#  'tactics': 32,
#  'russias': 32,
#  'sources': 32,
#  'arms': 32,
#  'facing': 32,
#  'cause': 32,
#  'ways': 32,
#  'severe': 32,
#  'recently': 32,
#  'higher': 32,
#  'mid': 32,
#  'arctic': 32,
#  'diseases': 32,
#  'shabaab': 32,
#  'area': 31,
#  'egypt': 31,
#  'another': 31,
#  'troops': 31,
#  'ground': 31,
#  'legitimacy': 31,
#  'extreme': 31,
#  'whether': 31,
#  'borders': 31,
#  'seen': 31,
#  'killed': 31,
#  'return': 31,
#  'cocaine': 31,
#  'sub': 31,
#  'displaced': 31,
#  'existing': 31,
#  'improved': 31,
#  'operating': 31,
#  'police': 31,
#  'export': 31,
#  'cruise': 31,
#  'tools': 31,
#  'demonstrated': 31,
#  'kim': 31,
#  'affect': 30,
#  'possible': 30,
#  'elsewhere': 30,
#  'propaganda': 30,
#  'conducting': 30,
#  'trend': 30,
#  'signs': 30,
#  'avoid': 30,
#  'negotiations': 30,
#  'moreover': 30,
#  'scientific': 30,
#  'promote': 30,
#  'longstanding': 30,
#  'present': 30,
#  'modernization': 30,
#  'wide': 30,
#  'cases': 30,
#  'politics': 30,
#  'pro': 30,
#  'agreements': 30,
#  'implementation': 30,
#  'approach': 30,
#  'disruptions': 30,
#  'june': 30,
#  'congo': 30,
#  'recovery': 30,
#  'cost': 30,
#  'turkish': 30,
#  'influenza': 29,
#  'worlds': 29,
#  'particular': 29,
#  'commitment': 29,
#  'muslims': 29,
#  'priorities': 29,
#  'greatest': 29,
#  'radical': 29,
#  'balance': 29,
#  'appears': 29,
#  'day': 29,
#  'point': 29,
#  'scope': 29,
#  'necessary': 29,
#  'neighbors': 29,
#  'costs': 29,
#  'ensure': 29,
#  'office': 29,
#  'authorities': 29,
#  'positive': 29,
#  'spring': 29,
#  'driven': 29,
#  'disputes': 29,
#  'pursuit': 29,
#  'mexican': 29,
#  'active': 29,
#  'position': 29,
#  'easily': 29,
#  'ruling': 29,
#  'steps': 29,
#  'successful': 29,
#  'inside': 29,
#  'shortages': 29,
#  'tension': 29,
#  'belarus': 29,
#  'director': 28,
#  'offer': 28,
#  'great': 28,
#  'arabia': 28,
#  'homegrown': 28,
#  'freedom': 28,
#  'iraqs': 28,
#  'positions': 28,
#  'limit': 28,
#  'moderate': 28,
#  'rapidly': 28,
#  'taiwan': 28,
#  'designed': 28,
#  'discontent': 28,
#  'operatives': 28,
#  'militias': 28,
#  'provincial': 28,
#  'entities': 28,
#  'industrial': 28,
#  'land': 28,
#  'estimated': 28,
#  'august': 28,
#  'launched': 28,
#  'gdp': 28,
#  'pla': 28,
#  'virus': 28,
#  'losses': 28,
#  'globalization': 27,
#  'sovereignty': 27,
#  'safety': 27,
#  'enabled': 27,
#  'multiple': 27,
#  'move': 27,
#  'becoming': 27,
#  'grow': 27,
#  'complex': 27,
#  'basic': 27,
#  'needed': 27,
#  'produced': 27,
#  'brazil': 27,
#  'declining': 27,
#  'environmental': 27,
#  'thousands': 27,
#  'affiliates': 27,
#  'april': 27,
#  'fiscal': 27,
#  'saharan': 27,
#  'eventually': 27,
#  'farc': 27,
#  'self': 26,
#  'launch': 26,
#  'independence': 26,
#  'personal': 26,
#  'depend': 26,
#  'fissile': 26,
#  'spending': 26,
#  'way': 26,
#  'sustain': 26,
#  'society': 26,
#  'post': 26,
#  'supplies': 26,
#  'short': 26,
#  'occur': 26,
#  'counterintelligence': 26,
#  'undermining': 26,
#  'maintaining': 26,
#  'civilian': 26,
#  'lower': 26,
#  'warning': 26,
#  'computer': 26,
#  'price': 26,
#  'putin': 26,
#  'cuban': 26,
#  'disruptive': 26,
#  'priority': 25,
#  'either': 25,
#  'devices': 25,
#  'working': 25,
#  'give': 25,
#  'needs': 25,
#  'caused': 25,
#  'profile': 25,
#  'terms': 25,
#  'revenues': 25,
#  'design': 25,
#  'cannot': 25,
#  'provides': 25,
#  'pyongyang': 25,
#  'damascus': 25,
#  'drive': 25,
#  'meanwhile': 25,
#  'real': 25,
#  'disruption': 25,
#  'producing': 25,
#  'strain': 25,
#  'backed': 25,
#  'bank': 25,
#  'cross': 25,
#  'established': 25,
#  'kremlin': 25,
#  'approximately': 25,
#  'rely': 25,
#  'commodity': 25,
#  'contribute': 25,
#  'communications': 25,
#  'globally': 25,
#  'ai': 25,
#  'chairman': 24,
#  'full': 24,
#  'confront': 24,
#  'different': 24,
#  'base': 24,
#  'statements': 24,
#  'establish': 24,
#  'travel': 24,
#  'broad': 24,
#  'front': 24,
#  'set': 24,
#  'dependent': 24,
#  'deployed': 24,
#  'deterrence': 24,
#  'reserves': 24,
#  'similar': 24,
#  'willing': 24,
#  'period': 24,
#  'raise': 24,
#  'legal': 24,
#  'sufficient': 24,
#  'unemployment': 24,
#  'traffickers': 24,
#  'involved': 24,
#  'haiti': 24,
#  'act': 24,
#  'sharing': 24,
#  'negative': 24,
#  'consequences': 24,
#  'declined': 24,
#  'times': 24,
#  'debt': 24,
#  'rebel': 24,
#  'sides': 24,
#  'balkans': 24,
#  'independent': 24,
#  'half': 24,
#  'decisionmaking': 24,
#  'aqim': 24,
#  'enhance': 24,
#  'declared': 24,
#  'projects': 24,
#  'enough': 24,
#  'field': 24,
#  'implications': 24,
#  'come': 24,
#  'quickly': 24,
#  'vital': 24,
#  'navy': 24,
#  'displacement': 24,
#  'lives': 23,
#  'operation': 23,
#  'performance': 23,
#  'divisions': 23,
#  'initiatives': 23,
#  'highest': 23,
#  'factors': 23,
#  'populist': 23,
#  'washington': 23,
#  'supporting': 23,
#  'generally': 23,
#  'persist': 23,
#  'legislative': 23,
#  'poverty': 23,
#  'industry': 23,
#  'darfur': 23,
#  'improvements': 23,
#  'leverage': 23,
#  'insecurity': 23,
#  'previous': 23,
#  'every': 23,
#  'life': 23,
#  'targeted': 23,
#  'availability': 23,
#  'believe': 23,
#  'joint': 23,
#  'select': 22,
#  'shared': 22,
#  'ahead': 22,
#  'bombings': 22,
#  'nonetheless': 22,
#  'pace': 22,
#  'constitutional': 22,
#  'provided': 22,
#  'desire': 22,
#  'decades': 22,
#  'heavily': 22,
#  'project': 22,
#  'currency': 22,
#  'deter': 22,
#  'undercut': 22,
#  'partner': 22,
#  'treaty': 22,
#  'corrupt': 22,
#  'side': 22,
#  'plots': 22,
#  'comprehensive': 22,
#  'keep': 22,
#  'infectious': 22,
#  'outbreak': 22,
#  'advances': 22,
#  'relationships': 22,
#  'planning': 22,
#  'six': 22,
#  'willingness': 22,
#  'directly': 22,
#  'generation': 22,
#  'naval': 22,
#  'dialogue': 22,
#  'caucasus': 22,
#  'authoritarian': 22,
#  'death': 22,
#  'sophistication': 22,
#  'reactor': 22,
#  'transit': 22,
#  'inflation': 22,
#  'satellite': 22,
#  'relative': 22,
#  'official': 22,
#  'aqap': 22,
#  'satellites': 22,
#  ...}

# %%
plt.figure(figsize = (20,20)) # Text that is not Fake
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800 , stopwords = STOPWORDS).fit_words(most_common_uni)
plt.imshow(wc , interpolation = 'bilinear')
plt.savefig('worldAll1', dpi=600)
plt.show()

# %%
tudo = pd.DataFrame(data = most_common_uni.values(), index = most_common_uni.keys(), columns = ['quantidade'])

# %% [markdown]
# #### Quantidade total de palavras

# %%
tudo.quantidade.sum()
# Out:
# 104434

# %%
tudo.quantidade
# Out:
# security              638
# economic              638
# political             539
# continue              514
# government            489
#                      ...
# ivan                    1
# fraying                 1
# miguel                  1
# institutionalizing      1
# canel                   1
# Name: quantidade, Length: 10581, dtype: int64

# %%
(tudo.quantidade / tudo.quantidade.sum())*100
# Out:
# security              0.610912
# economic              0.610912
# political             0.516115
# continue              0.492177
# government            0.468238
#                         ...
# ivan                  0.000958
# fraying               0.000958
# miguel                0.000958
# institutionalizing    0.000958
# canel                 0.000958
# Name: quantidade, Length: 10581, dtype: float64

# %%
most_common_bi = get_top_text_ngrams(df.text_b,2)
most_common_bi = dict(most_common_bi)
most_common_bi
# Out:
# {'al qaida': 201,
#  'statement record': 158,
#  'north korea': 136,
#  'ata feb': 135,
#  'feb statement': 135,
#  'nuclear weapons': 127,
#  'national security': 95,
#  'middle east': 94,
#  'almost certainly': 89,
#  'economic growth': 86,
#  'intelligence community': 84,
#  'climate change': 68,
#  'ballistic missiles': 62,
#  'long term': 61,
#  'foreign policy': 59,
#  'last year': 58,
#  'political economic': 58,
#  'terrorist groups': 57,
#  'security forces': 53,
#  'organized crime': 52,
#  'prime minister': 52,
#  'al qaidas': 51,
#  'latin america': 51,
#  'oil prices': 50,
#  'probably continue': 49,
#  'past year': 48,
#  'south asia': 45,
#  'international community': 44,
#  'next year': 44,
#  'sasc ata': 44,
#  'transnational organized': 43,
#  'likely continue': 42,
#  'east asia': 39,
#  'iraq syria': 38,
#  'private sector': 38,
#  'russia china': 38,
#  'rule law': 37,
#  'law enforcement': 36,
#  'ballistic missile': 35,
#  'chemical weapons': 33,
#  'terrorist attacks': 33,
#  'north africa': 33,
#  'central asia': 32,
#  'critical infrastructure': 32,
#  'non state': 30,
#  'al shabaab': 30,
#  'national intelligence': 29,
#  'financial crisis': 29,
#  'violent extremists': 29,
#  'saudi arabia': 28,
#  'cyber attacks': 28,
#  'cyber espionage': 28,
#  'cyber operations': 28,
#  'foreign intelligence': 27,
#  'sub saharan': 27,
#  'long range': 27,
#  'presidential election': 27,
#  'economic security': 26,
#  'south sudan': 26,
#  'coming year': 25,
#  'fissile material': 25,
#  'uranium enrichment': 25,
#  'human rights': 25,
#  'many countries': 25,
#  'global economy': 25,
#  'east africa': 25,
#  'western interests': 25,
#  'north korean': 25,
#  'threat assessment': 24,
#  'mass destruction': 24,
#  'militant groups': 24,
#  'large scale': 24,
#  'economic development': 24,
#  'dual use': 24,
#  'terrorist threat': 24,
#  'saharan africa': 24,
#  'information technology': 24,
#  'government officials': 24,
#  'security services': 24,
#  'weapons mass': 23,
#  'lebanese hizballah': 23,
#  'global economic': 23,
#  'armed forces': 23,
#  'two years': 23,
#  'near term': 23,
#  'mass atrocities': 23,
#  'southeast asia': 22,
#  'assess iran': 22,
#  'nuclear weapon': 22,
#  'nonstate actors': 22,
#  'sunni violent': 22,
#  'director national': 21,
#  'likely remain': 21,
#  'economic reforms': 21,
#  'new delhi': 21,
#  'iran continues': 21,
#  'central america': 21,
#  'certainly continue': 21,
#  'east north': 21,
#  'around world': 20,
#  'iraqi security': 20,
#  'five years': 20,
#  'extremist groups': 20,
#  'drug trafficking': 20,
#  'human trafficking': 20,
#  'global financial': 20,
#  'cyber attack': 20,
#  'iran north': 19,
#  'high profile': 19,
#  'shia militants': 19,
#  'persian gulf': 19,
#  'security interests': 19,
#  'could lead': 19,
#  'several years': 19,
#  'natural resources': 19,
#  'intelligence services': 19,
#  'iraqi government': 19,
#  'nuclear program': 19,
#  'russian military': 19,
#  'oil production': 19,
#  'military capabilities': 19,
#  'extreme weather': 19,
#  'threat interests': 18,
#  'india pakistan': 18,
#  'remain concerned': 18,
#  'chinese leaders': 18,
#  'central asian': 18,
#  'russia eurasia': 18,
#  'space systems': 18,
#  'democratic republic': 18,
#  'republic congo': 18,
#  'china russia': 18,
#  'arab spring': 18,
#  'political instability': 17,
#  'chemical biological': 17,
#  'security environment': 17,
#  'foreign fighters': 17,
#  'delivery systems': 17,
#  'criminal organizations': 17,
#  'north koreas': 17,
#  'oil gas': 17,
#  'state actors': 17,
#  'regional threats': 17,
#  'range ballistic': 17,
#  'violent extremist': 17,
#  'gdp growth': 17,
#  'past years': 17,
#  'economic crisis': 17,
#  'core al': 17,
#  'cyber threats': 17,
#  'china continue': 17,
#  'afghanistan pakistan': 16,
#  'slow economic': 16,
#  'major threat': 16,
#  'syrian regime': 16,
#  'economic conditions': 16,
#  'west africa': 16,
#  'china india': 16,
#  'groups continue': 16,
#  'conduct attacks': 16,
#  'several countries': 16,
#  'interests region': 16,
#  'continue assess': 16,
#  'assess north': 16,
#  'afghan national': 16,
#  'probably remain': 16,
#  'cruise missile': 16,
#  'threats interests': 16,
#  'denial service': 16,
#  'intelligence threats': 16,
#  'influence operations': 16,
#  'state intelligence': 15,
#  'national elections': 15,
#  'central government': 15,
#  'supreme leader': 15,
#  'asad regime': 15,
#  'civil society': 15,
#  'iran syria': 15,
#  'drug trade': 15,
#  'continue pose': 15,
#  'little warning': 15,
#  'enriched uranium': 15,
#  'cyber capabilities': 15,
#  'insurgent groups': 15,
#  'peace talks': 15,
#  'civil war': 15,
#  'military force': 15,
#  'foreign investment': 15,
#  'criminal groups': 15,
#  'next years': 15,
#  'worldwide threat': 15,
#  'social media': 15,
#  'global threats': 15,
#  'local regional': 15,
#  'human security': 15,
#  'global jihadist': 14,
#  'counterterrorism efforts': 14,
#  'deployed troops': 14,
#  'international security': 14,
#  'east south': 14,
#  'economic political': 14,
#  'natural gas': 14,
#  'recent years': 14,
#  'military operations': 14,
#  'ethnic tensions': 14,
#  'humanitarian crisis': 14,
#  'internally displaced': 14,
#  'coming years': 14,
#  'parliamentary elections': 14,
#  'assessment intelligence': 14,
#  'threats national': 14,
#  'use cyber': 14,
#  'cruise missiles': 14,
#  'wide range': 14,
#  'nuclear capabilities': 14,
#  'high levels': 14,
#  'global food': 14,
#  'south china': 14,
#  'kim jong': 14,
#  'developing countries': 14,
#  'continue pursue': 14,
#  'homegrown violent': 14,
#  'threats cyber': 14,
#  'members committee': 13,
#  'committee thank': 13,
#  'islamic state': 13,
#  'persistent threat': 13,
#  'dangerous technologies': 13,
#  'increase risk': 13,
#  'iraqi shia': 13,
#  'south korea': 13,
#  'eurasia russia': 13,
#  'former soviet': 13,
#  'presidential elections': 13,
#  'countries region': 13,
#  'neighboring countries': 13,
#  'allies partners': 13,
#  'biological chemical': 13,
#  'cyber threat': 13,
#  'longer term': 13,
#  'made progress': 13,
#  'emerging markets': 13,
#  'african union': 13,
#  'million people': 13,
#  'food water': 13,
#  'health care': 13,
#  'america caribbean': 13,
#  'boko haram': 13,
#  'western hemisphere': 13,
#  'senate select': 12,
#  'select committee': 12,
#  'committee intelligence': 12,
#  'interests overseas': 12,
#  'terrorist organizations': 12,
#  'political security': 12,
#  'iraq afghanistan': 12,
#  'progress toward': 12,
#  'political process': 12,
#  'afghan government': 12,
#  'globalized economy': 12,
#  'conventional military': 12,
#  'criminal activity': 12,
#  'terrorist group': 12,
#  'security concerns': 12,
#  'significant threat': 12,
#  'intelligence capabilities': 12,
#  'tribal areas': 12,
#  'central african': 12,
#  'african republic': 12,
#  'energy prices': 12,
#  'barrels per': 12,
#  'security challenges': 12,
#  'challenges facing': 12,
#  'iran would': 12,
#  'nuclear test': 12,
#  'nagorno karabakh': 12,
#  'global health': 12,
#  'continue use': 12,
#  'emerging market': 12,
#  'southeast asian': 12,
#  'china sea': 12,
#  'caucasus central': 12,
#  'public health': 12,
#  'state nonstate': 12,
#  'asia afghanistan': 12,
#  'water problems': 12,
#  'destruction proliferation': 12,
#  'thank invitation': 11,
#  'assessment threats': 11,
#  'anti western': 11,
#  'remain high': 11,
#  'leaders continue': 11,
#  'political leaders': 11,
#  'troops allies': 11,
#  'next decade': 11,
#  'inventory ballistic': 11,
#  'ahmadi nejad': 11,
#  'iran lebanese': 11,
#  'regional influence': 11,
#  'south korean': 11,
#  'legislative elections': 11,
#  'bilateral relationship': 11,
#  'democratic institutions': 11,
#  'peace agreement': 11,
#  'global energy': 11,
#  'china china': 11,
#  'environmental degradation': 11,
#  'military presence': 11,
#  'develop acquire': 11,
#  'easily globalized': 11,
#  'design use': 11,
#  'great power': 11,
#  'rebel groups': 11,
#  'pakistan based': 11,
#  'per day': 11,
#  'government private': 11,
#  'past two': 11,
#  'arabian peninsula': 11,
#  'high confidence': 11,
#  'commodity prices': 11,
#  'continues develop': 11,
#  'el salvador': 11,
#  'food prices': 11,
#  'countries including': 11,
#  'increasing risk': 11,
#  'violent extremism': 11,
#  'economic activity': 11,
#  'cross border': 11,
#  'continue face': 11,
#  'economic recovery': 11,
#  'weather events': 11,
#  'security issues': 11,
#  'security threats': 11,
#  'military forces': 11,
#  'space counterspace': 11,
#  'levels violence': 11,
#  'record worldwide': 11,
#  'euro zone': 11,
#  'asia china': 11,
#  'state iraq': 11,
#  'ground launched': 11,
#  'adversaries strategic': 11,
#  'vice chairman': 10,
#  'invitation offer': 10,
#  'economic social': 10,
#  'groups individuals': 10,
#  'popular support': 10,
#  'sunni arab': 10,
#  'remain significant': 10,
#  'efforts improve': 10,
#  'basic services': 10,
#  'new government': 10,
#  'security situation': 10,
#  'oil revenues': 10,
#  'continue try': 10,
#  'already largest': 10,
#  'largest inventory': 10,
#  'region including': 10,
#  'hold power': 10,
#  'ahmadi nejads': 10,
#  'qaida leaders': 10,
#  'political parties': 10,
#  'past decade': 10,
#  'military modernization': 10,
#  'irans nuclear': 10,
#  'oil exports': 10,
#  'crime groups': 10,
#  'infectious disease': 10,
#  'last summer': 10,
#  'two countries': 10,
#  'endemic corruption': 10,
#  'iraq levant': 10,
#  'soviet union': 10,
#  'public statements': 10,
#  'delivering nuclear': 10,
#  'three years': 10,
#  'state non': 10,
#  'cyber means': 10,
#  'northern iraq': 10,
#  'syria iraq': 10,
#  'peoples liberation': 10,
#  'asat weapons': 10,
#  'counterspace capabilities': 10,
#  'armed groups': 10,
#  'direct threat': 10,
#  'infectious diseases': 10,
#  'critical infrastructures': 10,
#  'low level': 10,
#  'primary threat': 10,
#  'expand influence': 10,
#  'influence region': 10,
#  'economic ties': 10,
#  'judge iran': 10,
#  'poor governance': 10,
#  'nuclear missile': 10,
#  'challenges including': 10,
#  'missile defense': 10,
#  'supply chains': 10,
#  'per barrel': 10,
#  'cyber security': 10,
#  'threat security': 10,
#  'communist party': 10,
#  'according un': 10,
#  'services continue': 10,
#  'russia iran': 10,
#  'jong un': 10,
#  'sudan south': 10,
#  'intelligence security': 10,
#  'road mobile': 10,
#  'syrian conflict': 10,
#  'inf treaty': 10,
#  'strategic competitors': 10,
#  'annual threat': 9,
#  'jihadist movement': 9,
#  'policymakers warfighters': 9,
#  'american lives': 9,
#  'attack homeland': 9,
#  'regional stability': 9,
#  'domestic stability': 9,
#  'nation state': 9,
#  'economic reform': 9,
#  'nuclear proliferation': 9,
#  'president ahmadi': 9,
#  'bashar al': 9,
#  'peace process': 9,
#  'home abroad': 9,
#  'political stability': 9,
#  'political power': 9,
#  'high rates': 9,
#  'pakistan india': 9,
#  'foreseeable future': 9,
#  'global oil': 9,
#  'financial support': 9,
#  'avian influenza': 9,
#  'around globe': 9,
#  'wmd proliferation': 9,
#  'un security': 9,
#  'security council': 9,
#  'potential adversaries': 9,
#  'latin american': 9,
#  'public dissatisfaction': 9,
#  'gain access': 9,
#  'short term': 9,
#  'community senate': 9,
#  'economic challenges': 9,
#  'intelligence communitys': 9,
#  'threat western': 9,
#  'terrorist attack': 9,
#  'efforts develop': 9,
#  'produce nuclear': 9,
#  'inherently capable': 9,
#  'iran eventually': 9,
#  'probably would': 9,
#  'national police': 9,
#  'drug related': 9,
#  'displaced persons': 9,
#  'maintain control': 9,
#  'probably increase': 9,
#  'border security': 9,
#  'nuclear forces': 9,
#  'classified statement': 9,
#  'drug cartels': 9,
#  'countries remain': 9,
#  'remain focused': 9,
#  'attacks west': 9,
#  'remain primary': 9,
#  'sunni extremists': 9,
#  'security force': 9,
#  'corrupt officials': 9,
#  'weapons programs': 9,
#  'economy personnel': 9,
#  'personnel scientific': 9,
#  'scientific expertise': 9,
#  'expertise design': 9,
#  'power projection': 9,
#  'poor economic': 9,
#  'food security': 9,
#  'build nuclear': 9,
#  'certainly remain': 9,
#  'growth rates': 9,
#  'information systems': 9,
#  'intellectual property': 9,
#  'security economic': 9,
#  'organized criminal': 9,
#  'transnational criminal': 9,
#  'relatively low': 9,
#  'cyber actors': 9,
#  'financial institutions': 9,
#  'sectarian tensions': 9,
#  'salvador guatemala': 9,
#  'natural disasters': 9,
#  'internal conflict': 9,
#  'high unemployment': 9,
#  'countries probably': 9,
#  'range challenges': 9,
#  'threat environment': 9,
#  'security information': 9,
#  'internet governance': 9,
#  'space services': 9,
#  'food insecurity': 9,
#  'pla navy': 9,
#  'range nuclear': 9,
#  'protect american': 8,
#  'coalition forces': 8,
#  'high level': 8,
#  'senior leaders': 8,
#  'small scale': 8,
#  'mass casualty': 8,
#  'challenges remain': 8,
#  'concerned threat': 8,
#  'production technologies': 8,
#  'regime threatening': 8,
#  'economic policies': 8,
#  'asia middle': 8,
#  'al asad': 8,
#  'high oil': 8,
#  'next several': 8,
#  'become increasingly': 8,
#  'humanitarian crises': 8,
#  'modernization program': 8,
#  'living standards': 8,
#  'pose significant': 8,
#  'small number': 8,
#  'time access': 8,
#  'access dangerous': 8,
#  'assess tehran': 8,
#  'develop nuclear': 8,
#  'missile programs': 8,
#  'criminal elements': 8,
#  'gaza strip': 8,
#  'raul castro': 8,
#  'might lead': 8,
#  'nuclear capability': 8,
#  'political opposition': 8,
#  'production capacity': 8,
#  'million barrels': 8,
#  'developing economies': 8,
#  'introduction chairman': 8,
#  'information infrastructure': 8,
#  'military intelligence': 8,
#  'africa middle': 8,
#  'threat homeland': 8,
#  'security measures': 8,
#  'assess al': 8,
#  'growing threat': 8,
#  'take advantage': 8,
#  'constitute major': 8,
#  'design weaponization': 8,
#  'capable delivering': 8,
#  'coercive diplomacy': 8,
#  'six party': 8,
#  'poppy cultivation': 8,
#  'forces isf': 8,
#  'communal violence': 8,
#  'remain fragile': 8,
#  'islamic revolutionary': 8,
#  'iranian officials': 8,
#  'attacks iraq': 8,
#  'internal security': 8,
#  'level violence': 8,
#  'strait hormuz': 8,
#  'anti ship': 8,
#  'led coalition': 8,
#  'syria iran': 8,
#  'economic situation': 8,
#  'weak institutions': 8,
#  'continue expand': 8,
#  'domestic political': 8,
#  'political system': 8,
#  'eu nato': 8,
#  'regional power': 8,
#  'pose threat': 8,
#  'continue seek': 8,
#  'revolutionary armed': 8,
#  'likely face': 8,
#  'russian influence': 8,
#  'water shortages': 8,
#  'hiv aids': 8,
#  'influenza pandemic': 8,
#  'international financial': 8,
#  'attack capabilities': 8,
#  'economic opportunities': 8,
#  'european countries': 8,
#  'attacks western': 8,
#  'financial aid': 8,
#  'declining oil': 8,
#  'source revenue': 8,
#  'materials technologies': 8,
#  'know whether': 8,
#  'nuclear reactor': 8,
#  'percent percent': 8,
#  'continue efforts': 8,
#  'thus far': 8,
#  'energy agency': 8,
#  'remain committed': 8,
#  'threat iran': 8,
#  'atomic energy': 8,
#  'military economic': 8,
#  'need protect': 8,
#  'space based': 8,
#  'homicide rates': 8,
#  'armenia azerbaijan': 8,
#  'western balkans': 8,
#  'money laundering': 8,
#  'extremists hves': 8,
#  'destruction wmd': 8,
#  'india china': 8,
#  'opposition groups': 8,
#  'regime change': 8,
#  'estimated million': 8,
#  'global growth': 8,
#  'every day': 8,
#  'central africa': 8,
#  'offensive cyber': 8,
#  'wmd delivery': 8,
#  'syria assess': 8,
#  'iran iran': 8,
#  'plan action': 8,
#  'advanced economies': 8,
#  'probably seek': 8,
#  'continue rely': 8,
#  'new generation': 8,
#  'jin class': 8,
#  'iranian backed': 8,
#  'intelligence february': 7,
#  'regions world': 7,
#  'social political': 7,
#  'biological radiological': 7,
#  'radiological nuclear': 7,
#  'since late': 7,
#  'pakistani militant': 7,
#  'global jihad': 7,
#  'middle eastern': 7,
#  'bin ladin': 7,
#  'key partners': 7,
#  'effective governance': 7,
#  'command control': 7,
#  'karzai government': 7,
#  'nation deployed': 7,
#  'threat destabilizing': 7,
#  'deterrence international': 7,
#  'widely available': 7,
#  'two decades': 7,
#  'missiles middle': 7,
#  'integral part': 7,
#  'shia dominated': 7,
#  'ability project': 7,
#  'continues support': 7,
#  'weapons program': 7,
#  'first time': 7,
#  'elections scheduled': 7,
#  'make progress': 7,
#  'confidence building': 7,
#  'rampant corruption': 7,
#  'remains committed': 7,
#  'president chavez': 7,
#  'economic military': 7,
#  'south africa': 7,
#  'regional global': 7,
#  'energy security': 7,
#  'security threat': 7,
#  'information available': 7,
#  'regional instability': 7,
#  'terrorist threats': 7,
#  'ongoing efforts': 7,
#  'ethno sectarian': 7,
#  'oil output': 7,
#  'led government': 7,
#  'qaida iraq': 7,
#  'koreas nuclear': 7,
#  'vis vis': 7,
#  'west bank': 7,
#  'unity government': 7,
#  'provide security': 7,
#  'federal government': 7,
#  'living conditions': 7,
#  'political unrest': 7,
#  'power status': 7,
#  'foreign exchange': 7,
#  'nuclear armed': 7,
#  'euro atlantic': 7,
#  'material nuclear': 7,
#  'food energy': 7,
#  'external operations': 7,
#  'would like': 7,
#  'northern mali': 7,
#  'judge al': 7,
#  'continue support': 7,
#  'growing number': 7,
#  'threat posed': 7,
#  'related materials': 7,
#  'materials technology': 7,
#  'missiles inherently': 7,
#  'longer range': 7,
#  'research development': 7,
#  'moderate confidence': 7,
#  'scientific technical': 7,
#  'policy objectives': 7,
#  'iran probably': 7,
#  'would need': 7,
#  'need produce': 7,
#  'highly enriched': 7,
#  'biological warfare': 7,
#  'produced nuclear': 7,
#  'pyongyang probably': 7,
#  'computer networks': 7,
#  'support afghan': 7,
#  'security assistance': 7,
#  'progress made': 7,
#  'revolutionary guard': 7,
#  'iranian leaders': 7,
#  'continue threaten': 7,
#  'oil price': 7,
#  'economic performance': 7,
#  'along line': 7,
#  'inter ethnic': 7,
#  'social services': 7,
#  'public expectations': 7,
#  'mass migration': 7,
#  'forces colombia': 7,
#  'drug traffickers': 7,
#  'niger delta': 7,
#  'political institutions': 7,
#  'increase global': 7,
#  'serious threat': 7,
#  'public support': 7,
#  'humanitarian assistance': 7,
#  'iranian influence': 7,
#  'including iran': 7,
#  'produce weapons': 7,
#  'indian leaders': 7,
#  'military leaders': 7,
#  'prestige coercive': 7,
#  'russia continues': 7,
#  'six months': 7,
#  'ethnic groups': 7,
#  'violent crime': 7,
#  'remain risk': 7,
#  'distributed denial': 7,
#  'rural areas': 7,
#  'state failure': 7,
#  'world bank': 7,
#  'health security': 7,
#  'likely increase': 7,
#  'national interests': 7,
#  'cyber activity': 7,
#  'use technology': 7,
#  'acquire weapons': 7,
#  'eventually decide': 7,
#  'decide build': 7,
#  'international atomic': 7,
#  'preferred method': 7,
#  'method delivering': 7,
#  'afghan taliban': 7,
#  'international support': 7,
#  'forces ansf': 7,
#  'attacks government': 7,
#  'territorial disputes': 7,
#  'new governments': 7,
#  'state state': 7,
#  'violence corruption': 7,
#  'military conflict': 7,
#  'union mission': 7,
#  'mission somalia': 7,
#  'somalia amisom': 7,
#  'threaten interests': 7,
#  'mass killing': 7,
#  'disease outbreaks': 7,
#  'every country': 7,
#  'weak governance': 7,
#  'safe havens': 7,
#  'state efforts': 7,
#  'chemical materials': 7,
#  'always dual': 7,
#  'latest discoveries': 7,
#  'discoveries life': 7,
#  'life sciences': 7,
#  'trusted insiders': 7,
#  'ukraine belarus': 7,
#  'pose risk': 7,
#  'drug threat': 7,
#  'since taking': 7,
#  'economic national': 7,
#  'toc networks': 7,
#  'social disruptions': 7,
#  'water related': 7,
#  'water sharing': 7,
#  'community committed': 7,
#  'committed every': 7,
#  'intelligence policymakers': 7,
#  'domestic law': 7,
#  'used preparation': 7,
#  'preparation assessment': 7,
#  'illicit trade': 7,
#  'heat waves': 7,
#  'water infrastructure': 7,
#  'european union': 7,
#  'president vladimir': 7,
#  'vladimir putin': 7,
#  'moldova belarus': 7,
#  'separatist region': 7,
#  'data deletion': 7,
#  'intelligence entities': 7,
#  'developing long': 7,
#  'interest rates': 7,
#  'syrian refugees': 7,
#  'assess russia': 7,
#  'russia continue': 7,
#  'cyber tools': 7,
#  'nuclear powered': 7,
#  'sea based': 7,
#  'capital outflows': 7,
#  'genome editing': 7,
#  'human displacement': 7,
#  'saudi led': 7,
#  'online influence': 7,
#  'offer assessment': 6,
#  'wmd related': 6,
#  'bin ladins': 6,
#  'operational capabilities': 6,
#  'nuclear materials': 6,
#  'interests worldwide': 6,
#  'capable conducting': 6,
#  'scale attacks': 6,
#  'interests abroad': 6,
#  'near east': 6,
#  'islamic extremists': 6,
#  'continue exploit': 6,
#  'suicide attacks': 6,
#  'improvised explosive': 6,
#  'throughout country': 6,
#  'electric power': 6,
#  'foreign aid': 6,
#  'afghan leaders': 6,
#  'geographic scope': 6,
#  'depend heavily': 6,
#  'safety nation': 6,
#  'constraints may': 6,
#  'utility preventing': 6,
#  'many years': 6,
#  'use move': 6,
#  'weapons assess': 6,
#  'assess countries': 6,
#  'programs continue': 6,
#  'iran seeks': 6,
#  'iran already': 6,
#  'tehran views': 6,
#  'part strategy': 6,
#  'necessary retaliate': 6,
#  'including forces': 6,
#  'threatening instability': 6,
#  'financial resources': 6,
#  'project military': 6,
#  'israeli palestinian': 6,
#  'attacks interests': 6,
#  'africa asia': 6,
#  'political military': 6,
#  'presidential legislative': 6,
#  'major source': 6,
#  'building measures': 6,
#  'ties iran': 6,
#  'continue deteriorate': 6,
#  'worlds largest': 6,
#  'five year': 6,
#  'sudan nigeria': 6,
#  'national unity': 6,
#  'ethno religious': 6,
#  'criminal networks': 6,
#  'political influence': 6,
#  'improve governance': 6,
#  'technical capabilities': 6,
#  'energy markets': 6,
#  'millions people': 6,
#  'greatest threat': 6,
#  'attacks homeland': 6,
#  'foreign governments': 6,
#  'ansar al': 6,
#  'positive developments': 6,
#  'electrical power': 6,
#  'iraq aqi': 6,
#  'across borders': 6,
#  'country faces': 6,
#  'islamic extremism': 6,
#  'become even': 6,
#  'use technologies': 6,
#  'iranian nuclear': 6,
#  'power influence': 6,
#  'lesser extent': 6,
#  'challenges interests': 6,
#  'hizballah hamas': 6,
#  'lebanon lebanon': 6,
#  'palestinian territories': 6,
#  'horn africa': 6,
#  'million internally': 6,
#  'transitional federal': 6,
#  'southern somalia': 6,
#  'major powers': 6,
#  'medium range': 6,
#  'financial system': 6,
#  'exchange reserves': 6,
#  'based militants': 6,
#  'concerned potential': 6,
#  'russia russia': 6,
#  'domestic foreign': 6,
#  'political situation': 6,
#  'atlantic integration': 6,
#  'military advantages': 6,
#  'continues pursue': 6,
#  'nuclear capable': 6,
#  'could threaten': 6,
#  'qaida affiliates': 6,
#  'usama bin': 6,
#  'ayman al': 6,
#  'al zawahiri': 6,
#  'significant economic': 6,
#  'significant damage': 6,
#  'related activities': 6,
#  'range missiles': 6,
#  'use nuclear': 6,
#  'iran scientific': 6,
#  'technical industrial': 6,
#  'industrial capacity': 6,
#  'capacity eventually': 6,
#  'eventually produce': 6,
#  'iran made': 6,
#  'still faces': 6,
#  'enrichment capability': 6,
#  'attempt use': 6,
#  'nuclear facilities': 6,
#  'virtually every': 6,
#  'including russia': 6,
#  'taliban dominated': 6,
#  'dominated insurgency': 6,
#  'governments ability': 6,
#  'economic opportunity': 6,
#  'operational tempo': 6,
#  'approximately percent': 6,
#  'government authority': 6,
#  'record levels': 6,
#  'influence iraq': 6,
#  'lethal aid': 6,
#  'take place': 6,
#  'according press': 6,
#  'ship cruise': 6,
#  'resistance israel': 6,
#  'coalition government': 6,
#  'syrian opposition': 6,
#  'political developments': 6,
#  'remain vulnerable': 6,
#  'line contact': 6,
#  'northern kosovo': 6,
#  'likely slow': 6,
#  'liberation army': 6,
#  'missile capabilities': 6,
#  'countries particularly': 6,
#  'raising risk': 6,
#  'colombia farc': 6,
#  'parts africa': 6,
#  'darfur region': 6,
#  'north south': 6,
#  'counterinsurgency operations': 6,
#  'political uncertainty': 6,
#  'gulf oil': 6,
#  'oil facilities': 6,
#  'political violence': 6,
#  'billions dollars': 6,
#  'estimated billion': 6,
#  'oil companies': 6,
#  'past five': 6,
#  'would likely': 6,
#  'economic financial': 6,
#  'foreign direct': 6,
#  'economic problems': 6,
#  'since fall': 6,
#  'operating environment': 6,
#  'based al': 6,
#  'european governments': 6,
#  'western targets': 6,
#  'use military': 6,
#  'iran continue': 6,
#  'sectarian violence': 6,
#  'within syria': 6,
#  'improve relations': 6,
#  'armed conflict': 6,
#  'parts country': 6,
#  'opium prices': 6,
#  'terrorist insurgent': 6,
#  'low enriched': 6,
#  'whether iran': 6,
#  'domestic priorities': 6,
#  'past several': 6,
#  'political support': 6,
#  'international prestige': 6,
#  'missiles associated': 6,
#  'associated materials': 6,
#  'nuclear technology': 6,
#  'economic downturn': 6,
#  'foreign military': 6,
#  'pose greatest': 6,
#  'growth rate': 6,
#  ...}

# %%
plt.figure(figsize = (16,9))
sns.barplot(x=list(most_common_bi.values())[:30],y=list(most_common_bi.keys())[:30])
plt.show()

# %%
most_common_bi
# Out:
# {'al qaida': 201,
#  'statement record': 158,
#  'north korea': 136,
#  'ata feb': 135,
#  'feb statement': 135,
#  'nuclear weapons': 127,
#  'national security': 95,
#  'middle east': 94,
#  'almost certainly': 89,
#  'economic growth': 86,
#  'intelligence community': 84,
#  'climate change': 68,
#  'ballistic missiles': 62,
#  'long term': 61,
#  'foreign policy': 59,
#  'last year': 58,
#  'political economic': 58,
#  'terrorist groups': 57,
#  'security forces': 53,
#  'organized crime': 52,
#  'prime minister': 52,
#  'al qaidas': 51,
#  'latin america': 51,
#  'oil prices': 50,
#  'probably continue': 49,
#  'past year': 48,
#  'south asia': 45,
#  'international community': 44,
#  'next year': 44,
#  'sasc ata': 44,
#  'transnational organized': 43,
#  'likely continue': 42,
#  'east asia': 39,
#  'iraq syria': 38,
#  'private sector': 38,
#  'russia china': 38,
#  'rule law': 37,
#  'law enforcement': 36,
#  'ballistic missile': 35,
#  'chemical weapons': 33,
#  'terrorist attacks': 33,
#  'north africa': 33,
#  'central asia': 32,
#  'critical infrastructure': 32,
#  'non state': 30,
#  'al shabaab': 30,
#  'national intelligence': 29,
#  'financial crisis': 29,
#  'violent extremists': 29,
#  'saudi arabia': 28,
#  'cyber attacks': 28,
#  'cyber espionage': 28,
#  'cyber operations': 28,
#  'foreign intelligence': 27,
#  'sub saharan': 27,
#  'long range': 27,
#  'presidential election': 27,
#  'economic security': 26,
#  'south sudan': 26,
#  'coming year': 25,
#  'fissile material': 25,
#  'uranium enrichment': 25,
#  'human rights': 25,
#  'many countries': 25,
#  'global economy': 25,
#  'east africa': 25,
#  'western interests': 25,
#  'north korean': 25,
#  'threat assessment': 24,
#  'mass destruction': 24,
#  'militant groups': 24,
#  'large scale': 24,
#  'economic development': 24,
#  'dual use': 24,
#  'terrorist threat': 24,
#  'saharan africa': 24,
#  'information technology': 24,
#  'government officials': 24,
#  'security services': 24,
#  'weapons mass': 23,
#  'lebanese hizballah': 23,
#  'global economic': 23,
#  'armed forces': 23,
#  'two years': 23,
#  'near term': 23,
#  'mass atrocities': 23,
#  'southeast asia': 22,
#  'assess iran': 22,
#  'nuclear weapon': 22,
#  'nonstate actors': 22,
#  'sunni violent': 22,
#  'director national': 21,
#  'likely remain': 21,
#  'economic reforms': 21,
#  'new delhi': 21,
#  'iran continues': 21,
#  'central america': 21,
#  'certainly continue': 21,
#  'east north': 21,
#  'around world': 20,
#  'iraqi security': 20,
#  'five years': 20,
#  'extremist groups': 20,
#  'drug trafficking': 20,
#  'human trafficking': 20,
#  'global financial': 20,
#  'cyber attack': 20,
#  'iran north': 19,
#  'high profile': 19,
#  'shia militants': 19,
#  'persian gulf': 19,
#  'security interests': 19,
#  'could lead': 19,
#  'several years': 19,
#  'natural resources': 19,
#  'intelligence services': 19,
#  'iraqi government': 19,
#  'nuclear program': 19,
#  'russian military': 19,
#  'oil production': 19,
#  'military capabilities': 19,
#  'extreme weather': 19,
#  'threat interests': 18,
#  'india pakistan': 18,
#  'remain concerned': 18,
#  'chinese leaders': 18,
#  'central asian': 18,
#  'russia eurasia': 18,
#  'space systems': 18,
#  'democratic republic': 18,
#  'republic congo': 18,
#  'china russia': 18,
#  'arab spring': 18,
#  'political instability': 17,
#  'chemical biological': 17,
#  'security environment': 17,
#  'foreign fighters': 17,
#  'delivery systems': 17,
#  'criminal organizations': 17,
#  'north koreas': 17,
#  'oil gas': 17,
#  'state actors': 17,
#  'regional threats': 17,
#  'range ballistic': 17,
#  'violent extremist': 17,
#  'gdp growth': 17,
#  'past years': 17,
#  'economic crisis': 17,
#  'core al': 17,
#  'cyber threats': 17,
#  'china continue': 17,
#  'afghanistan pakistan': 16,
#  'slow economic': 16,
#  'major threat': 16,
#  'syrian regime': 16,
#  'economic conditions': 16,
#  'west africa': 16,
#  'china india': 16,
#  'groups continue': 16,
#  'conduct attacks': 16,
#  'several countries': 16,
#  'interests region': 16,
#  'continue assess': 16,
#  'assess north': 16,
#  'afghan national': 16,
#  'probably remain': 16,
#  'cruise missile': 16,
#  'threats interests': 16,
#  'denial service': 16,
#  'intelligence threats': 16,
#  'influence operations': 16,
#  'state intelligence': 15,
#  'national elections': 15,
#  'central government': 15,
#  'supreme leader': 15,
#  'asad regime': 15,
#  'civil society': 15,
#  'iran syria': 15,
#  'drug trade': 15,
#  'continue pose': 15,
#  'little warning': 15,
#  'enriched uranium': 15,
#  'cyber capabilities': 15,
#  'insurgent groups': 15,
#  'peace talks': 15,
#  'civil war': 15,
#  'military force': 15,
#  'foreign investment': 15,
#  'criminal groups': 15,
#  'next years': 15,
#  'worldwide threat': 15,
#  'social media': 15,
#  'global threats': 15,
#  'local regional': 15,
#  'human security': 15,
#  'global jihadist': 14,
#  'counterterrorism efforts': 14,
#  'deployed troops': 14,
#  'international security': 14,
#  'east south': 14,
#  'economic political': 14,
#  'natural gas': 14,
#  'recent years': 14,
#  'military operations': 14,
#  'ethnic tensions': 14,
#  'humanitarian crisis': 14,
#  'internally displaced': 14,
#  'coming years': 14,
#  'parliamentary elections': 14,
#  'assessment intelligence': 14,
#  'threats national': 14,
#  'use cyber': 14,
#  'cruise missiles': 14,
#  'wide range': 14,
#  'nuclear capabilities': 14,
#  'high levels': 14,
#  'global food': 14,
#  'south china': 14,
#  'kim jong': 14,
#  'developing countries': 14,
#  'continue pursue': 14,
#  'homegrown violent': 14,
#  'threats cyber': 14,
#  'members committee': 13,
#  'committee thank': 13,
#  'islamic state': 13,
#  'persistent threat': 13,
#  'dangerous technologies': 13,
#  'increase risk': 13,
#  'iraqi shia': 13,
#  'south korea': 13,
#  'eurasia russia': 13,
#  'former soviet': 13,
#  'presidential elections': 13,
#  'countries region': 13,
#  'neighboring countries': 13,
#  'allies partners': 13,
#  'biological chemical': 13,
#  'cyber threat': 13,
#  'longer term': 13,
#  'made progress': 13,
#  'emerging markets': 13,
#  'african union': 13,
#  'million people': 13,
#  'food water': 13,
#  'health care': 13,
#  'america caribbean': 13,
#  'boko haram': 13,
#  'western hemisphere': 13,
#  'senate select': 12,
#  'select committee': 12,
#  'committee intelligence': 12,
#  'interests overseas': 12,
#  'terrorist organizations': 12,
#  'political security': 12,
#  'iraq afghanistan': 12,
#  'progress toward': 12,
#  'political process': 12,
#  'afghan government': 12,
#  'globalized economy': 12,
#  'conventional military': 12,
#  'criminal activity': 12,
#  'terrorist group': 12,
#  'security concerns': 12,
#  'significant threat': 12,
#  'intelligence capabilities': 12,
#  'tribal areas': 12,
#  'central african': 12,
#  'african republic': 12,
#  'energy prices': 12,
#  'barrels per': 12,
#  'security challenges': 12,
#  'challenges facing': 12,
#  'iran would': 12,
#  'nuclear test': 12,
#  'nagorno karabakh': 12,
#  'global health': 12,
#  'continue use': 12,
#  'emerging market': 12,
#  'southeast asian': 12,
#  'china sea': 12,
#  'caucasus central': 12,
#  'public health': 12,
#  'state nonstate': 12,
#  'asia afghanistan': 12,
#  'water problems': 12,
#  'destruction proliferation': 12,
#  'thank invitation': 11,
#  'assessment threats': 11,
#  'anti western': 11,
#  'remain high': 11,
#  'leaders continue': 11,
#  'political leaders': 11,
#  'troops allies': 11,
#  'next decade': 11,
#  'inventory ballistic': 11,
#  'ahmadi nejad': 11,
#  'iran lebanese': 11,
#  'regional influence': 11,
#  'south korean': 11,
#  'legislative elections': 11,
#  'bilateral relationship': 11,
#  'democratic institutions': 11,
#  'peace agreement': 11,
#  'global energy': 11,
#  'china china': 11,
#  'environmental degradation': 11,
#  'military presence': 11,
#  'develop acquire': 11,
#  'easily globalized': 11,
#  'design use': 11,
#  'great power': 11,
#  'rebel groups': 11,
#  'pakistan based': 11,
#  'per day': 11,
#  'government private': 11,
#  'past two': 11,
#  'arabian peninsula': 11,
#  'high confidence': 11,
#  'commodity prices': 11,
#  'continues develop': 11,
#  'el salvador': 11,
#  'food prices': 11,
#  'countries including': 11,
#  'increasing risk': 11,
#  'violent extremism': 11,
#  'economic activity': 11,
#  'cross border': 11,
#  'continue face': 11,
#  'economic recovery': 11,
#  'weather events': 11,
#  'security issues': 11,
#  'security threats': 11,
#  'military forces': 11,
#  'space counterspace': 11,
#  'levels violence': 11,
#  'record worldwide': 11,
#  'euro zone': 11,
#  'asia china': 11,
#  'state iraq': 11,
#  'ground launched': 11,
#  'adversaries strategic': 11,
#  'vice chairman': 10,
#  'invitation offer': 10,
#  'economic social': 10,
#  'groups individuals': 10,
#  'popular support': 10,
#  'sunni arab': 10,
#  'remain significant': 10,
#  'efforts improve': 10,
#  'basic services': 10,
#  'new government': 10,
#  'security situation': 10,
#  'oil revenues': 10,
#  'continue try': 10,
#  'already largest': 10,
#  'largest inventory': 10,
#  'region including': 10,
#  'hold power': 10,
#  'ahmadi nejads': 10,
#  'qaida leaders': 10,
#  'political parties': 10,
#  'past decade': 10,
#  'military modernization': 10,
#  'irans nuclear': 10,
#  'oil exports': 10,
#  'crime groups': 10,
#  'infectious disease': 10,
#  'last summer': 10,
#  'two countries': 10,
#  'endemic corruption': 10,
#  'iraq levant': 10,
#  'soviet union': 10,
#  'public statements': 10,
#  'delivering nuclear': 10,
#  'three years': 10,
#  'state non': 10,
#  'cyber means': 10,
#  'northern iraq': 10,
#  'syria iraq': 10,
#  'peoples liberation': 10,
#  'asat weapons': 10,
#  'counterspace capabilities': 10,
#  'armed groups': 10,
#  'direct threat': 10,
#  'infectious diseases': 10,
#  'critical infrastructures': 10,
#  'low level': 10,
#  'primary threat': 10,
#  'expand influence': 10,
#  'influence region': 10,
#  'economic ties': 10,
#  'judge iran': 10,
#  'poor governance': 10,
#  'nuclear missile': 10,
#  'challenges including': 10,
#  'missile defense': 10,
#  'supply chains': 10,
#  'per barrel': 10,
#  'cyber security': 10,
#  'threat security': 10,
#  'communist party': 10,
#  'according un': 10,
#  'services continue': 10,
#  'russia iran': 10,
#  'jong un': 10,
#  'sudan south': 10,
#  'intelligence security': 10,
#  'road mobile': 10,
#  'syrian conflict': 10,
#  'inf treaty': 10,
#  'strategic competitors': 10,
#  'annual threat': 9,
#  'jihadist movement': 9,
#  'policymakers warfighters': 9,
#  'american lives': 9,
#  'attack homeland': 9,
#  'regional stability': 9,
#  'domestic stability': 9,
#  'nation state': 9,
#  'economic reform': 9,
#  'nuclear proliferation': 9,
#  'president ahmadi': 9,
#  'bashar al': 9,
#  'peace process': 9,
#  'home abroad': 9,
#  'political stability': 9,
#  'political power': 9,
#  'high rates': 9,
#  'pakistan india': 9,
#  'foreseeable future': 9,
#  'global oil': 9,
#  'financial support': 9,
#  'avian influenza': 9,
#  'around globe': 9,
#  'wmd proliferation': 9,
#  'un security': 9,
#  'security council': 9,
#  'potential adversaries': 9,
#  'latin american': 9,
#  'public dissatisfaction': 9,
#  'gain access': 9,
#  'short term': 9,
#  'community senate': 9,
#  'economic challenges': 9,
#  'intelligence communitys': 9,
#  'threat western': 9,
#  'terrorist attack': 9,
#  'efforts develop': 9,
#  'produce nuclear': 9,
#  'inherently capable': 9,
#  'iran eventually': 9,
#  'probably would': 9,
#  'national police': 9,
#  'drug related': 9,
#  'displaced persons': 9,
#  'maintain control': 9,
#  'probably increase': 9,
#  'border security': 9,
#  'nuclear forces': 9,
#  'classified statement': 9,
#  'drug cartels': 9,
#  'countries remain': 9,
#  'remain focused': 9,
#  'attacks west': 9,
#  'remain primary': 9,
#  'sunni extremists': 9,
#  'security force': 9,
#  'corrupt officials': 9,
#  'weapons programs': 9,
#  'economy personnel': 9,
#  'personnel scientific': 9,
#  'scientific expertise': 9,
#  'expertise design': 9,
#  'power projection': 9,
#  'poor economic': 9,
#  'food security': 9,
#  'build nuclear': 9,
#  'certainly remain': 9,
#  'growth rates': 9,
#  'information systems': 9,
#  'intellectual property': 9,
#  'security economic': 9,
#  'organized criminal': 9,
#  'transnational criminal': 9,
#  'relatively low': 9,
#  'cyber actors': 9,
#  'financial institutions': 9,
#  'sectarian tensions': 9,
#  'salvador guatemala': 9,
#  'natural disasters': 9,
#  'internal conflict': 9,
#  'high unemployment': 9,
#  'countries probably': 9,
#  'range challenges': 9,
#  'threat environment': 9,
#  'security information': 9,
#  'internet governance': 9,
#  'space services': 9,
#  'food insecurity': 9,
#  'pla navy': 9,
#  'range nuclear': 9,
#  'protect american': 8,
#  'coalition forces': 8,
#  'high level': 8,
#  'senior leaders': 8,
#  'small scale': 8,
#  'mass casualty': 8,
#  'challenges remain': 8,
#  'concerned threat': 8,
#  'production technologies': 8,
#  'regime threatening': 8,
#  'economic policies': 8,
#  'asia middle': 8,
#  'al asad': 8,
#  'high oil': 8,
#  'next several': 8,
#  'become increasingly': 8,
#  'humanitarian crises': 8,
#  'modernization program': 8,
#  'living standards': 8,
#  'pose significant': 8,
#  'small number': 8,
#  'time access': 8,
#  'access dangerous': 8,
#  'assess tehran': 8,
#  'develop nuclear': 8,
#  'missile programs': 8,
#  'criminal elements': 8,
#  'gaza strip': 8,
#  'raul castro': 8,
#  'might lead': 8,
#  'nuclear capability': 8,
#  'political opposition': 8,
#  'production capacity': 8,
#  'million barrels': 8,
#  'developing economies': 8,
#  'introduction chairman': 8,
#  'information infrastructure': 8,
#  'military intelligence': 8,
#  'africa middle': 8,
#  'threat homeland': 8,
#  'security measures': 8,
#  'assess al': 8,
#  'growing threat': 8,
#  'take advantage': 8,
#  'constitute major': 8,
#  'design weaponization': 8,
#  'capable delivering': 8,
#  'coercive diplomacy': 8,
#  'six party': 8,
#  'poppy cultivation': 8,
#  'forces isf': 8,
#  'communal violence': 8,
#  'remain fragile': 8,
#  'islamic revolutionary': 8,
#  'iranian officials': 8,
#  'attacks iraq': 8,
#  'internal security': 8,
#  'level violence': 8,
#  'strait hormuz': 8,
#  'anti ship': 8,
#  'led coalition': 8,
#  'syria iran': 8,
#  'economic situation': 8,
#  'weak institutions': 8,
#  'continue expand': 8,
#  'domestic political': 8,
#  'political system': 8,
#  'eu nato': 8,
#  'regional power': 8,
#  'pose threat': 8,
#  'continue seek': 8,
#  'revolutionary armed': 8,
#  'likely face': 8,
#  'russian influence': 8,
#  'water shortages': 8,
#  'hiv aids': 8,
#  'influenza pandemic': 8,
#  'international financial': 8,
#  'attack capabilities': 8,
#  'economic opportunities': 8,
#  'european countries': 8,
#  'attacks western': 8,
#  'financial aid': 8,
#  'declining oil': 8,
#  'source revenue': 8,
#  'materials technologies': 8,
#  'know whether': 8,
#  'nuclear reactor': 8,
#  'percent percent': 8,
#  'continue efforts': 8,
#  'thus far': 8,
#  'energy agency': 8,
#  'remain committed': 8,
#  'threat iran': 8,
#  'atomic energy': 8,
#  'military economic': 8,
#  'need protect': 8,
#  'space based': 8,
#  'homicide rates': 8,
#  'armenia azerbaijan': 8,
#  'western balkans': 8,
#  'money laundering': 8,
#  'extremists hves': 8,
#  'destruction wmd': 8,
#  'india china': 8,
#  'opposition groups': 8,
#  'regime change': 8,
#  'estimated million': 8,
#  'global growth': 8,
#  'every day': 8,
#  'central africa': 8,
#  'offensive cyber': 8,
#  'wmd delivery': 8,
#  'syria assess': 8,
#  'iran iran': 8,
#  'plan action': 8,
#  'advanced economies': 8,
#  'probably seek': 8,
#  'continue rely': 8,
#  'new generation': 8,
#  'jin class': 8,
#  'iranian backed': 8,
#  'intelligence february': 7,
#  'regions world': 7,
#  'social political': 7,
#  'biological radiological': 7,
#  'radiological nuclear': 7,
#  'since late': 7,
#  'pakistani militant': 7,
#  'global jihad': 7,
#  'middle eastern': 7,
#  'bin ladin': 7,
#  'key partners': 7,
#  'effective governance': 7,
#  'command control': 7,
#  'karzai government': 7,
#  'nation deployed': 7,
#  'threat destabilizing': 7,
#  'deterrence international': 7,
#  'widely available': 7,
#  'two decades': 7,
#  'missiles middle': 7,
#  'integral part': 7,
#  'shia dominated': 7,
#  'ability project': 7,
#  'continues support': 7,
#  'weapons program': 7,
#  'first time': 7,
#  'elections scheduled': 7,
#  'make progress': 7,
#  'confidence building': 7,
#  'rampant corruption': 7,
#  'remains committed': 7,
#  'president chavez': 7,
#  'economic military': 7,
#  'south africa': 7,
#  'regional global': 7,
#  'energy security': 7,
#  'security threat': 7,
#  'information available': 7,
#  'regional instability': 7,
#  'terrorist threats': 7,
#  'ongoing efforts': 7,
#  'ethno sectarian': 7,
#  'oil output': 7,
#  'led government': 7,
#  'qaida iraq': 7,
#  'koreas nuclear': 7,
#  'vis vis': 7,
#  'west bank': 7,
#  'unity government': 7,
#  'provide security': 7,
#  'federal government': 7,
#  'living conditions': 7,
#  'political unrest': 7,
#  'power status': 7,
#  'foreign exchange': 7,
#  'nuclear armed': 7,
#  'euro atlantic': 7,
#  'material nuclear': 7,
#  'food energy': 7,
#  'external operations': 7,
#  'would like': 7,
#  'northern mali': 7,
#  'judge al': 7,
#  'continue support': 7,
#  'growing number': 7,
#  'threat posed': 7,
#  'related materials': 7,
#  'materials technology': 7,
#  'missiles inherently': 7,
#  'longer range': 7,
#  'research development': 7,
#  'moderate confidence': 7,
#  'scientific technical': 7,
#  'policy objectives': 7,
#  'iran probably': 7,
#  'would need': 7,
#  'need produce': 7,
#  'highly enriched': 7,
#  'biological warfare': 7,
#  'produced nuclear': 7,
#  'pyongyang probably': 7,
#  'computer networks': 7,
#  'support afghan': 7,
#  'security assistance': 7,
#  'progress made': 7,
#  'revolutionary guard': 7,
#  'iranian leaders': 7,
#  'continue threaten': 7,
#  'oil price': 7,
#  'economic performance': 7,
#  'along line': 7,
#  'inter ethnic': 7,
#  'social services': 7,
#  'public expectations': 7,
#  'mass migration': 7,
#  'forces colombia': 7,
#  'drug traffickers': 7,
#  'niger delta': 7,
#  'political institutions': 7,
#  'increase global': 7,
#  'serious threat': 7,
#  'public support': 7,
#  'humanitarian assistance': 7,
#  'iranian influence': 7,
#  'including iran': 7,
#  'produce weapons': 7,
#  'indian leaders': 7,
#  'military leaders': 7,
#  'prestige coercive': 7,
#  'russia continues': 7,
#  'six months': 7,
#  'ethnic groups': 7,
#  'violent crime': 7,
#  'remain risk': 7,
#  'distributed denial': 7,
#  'rural areas': 7,
#  'state failure': 7,
#  'world bank': 7,
#  'health security': 7,
#  'likely increase': 7,
#  'national interests': 7,
#  'cyber activity': 7,
#  'use technology': 7,
#  'acquire weapons': 7,
#  'eventually decide': 7,
#  'decide build': 7,
#  'international atomic': 7,
#  'preferred method': 7,
#  'method delivering': 7,
#  'afghan taliban': 7,
#  'international support': 7,
#  'forces ansf': 7,
#  'attacks government': 7,
#  'territorial disputes': 7,
#  'new governments': 7,
#  'state state': 7,
#  'violence corruption': 7,
#  'military conflict': 7,
#  'union mission': 7,
#  'mission somalia': 7,
#  'somalia amisom': 7,
#  'threaten interests': 7,
#  'mass killing': 7,
#  'disease outbreaks': 7,
#  'every country': 7,
#  'weak governance': 7,
#  'safe havens': 7,
#  'state efforts': 7,
#  'chemical materials': 7,
#  'always dual': 7,
#  'latest discoveries': 7,
#  'discoveries life': 7,
#  'life sciences': 7,
#  'trusted insiders': 7,
#  'ukraine belarus': 7,
#  'pose risk': 7,
#  'drug threat': 7,
#  'since taking': 7,
#  'economic national': 7,
#  'toc networks': 7,
#  'social disruptions': 7,
#  'water related': 7,
#  'water sharing': 7,
#  'community committed': 7,
#  'committed every': 7,
#  'intelligence policymakers': 7,
#  'domestic law': 7,
#  'used preparation': 7,
#  'preparation assessment': 7,
#  'illicit trade': 7,
#  'heat waves': 7,
#  'water infrastructure': 7,
#  'european union': 7,
#  'president vladimir': 7,
#  'vladimir putin': 7,
#  'moldova belarus': 7,
#  'separatist region': 7,
#  'data deletion': 7,
#  'intelligence entities': 7,
#  'developing long': 7,
#  'interest rates': 7,
#  'syrian refugees': 7,
#  'assess russia': 7,
#  'russia continue': 7,
#  'cyber tools': 7,
#  'nuclear powered': 7,
#  'sea based': 7,
#  'capital outflows': 7,
#  'genome editing': 7,
#  'human displacement': 7,
#  'saudi led': 7,
#  'online influence': 7,
#  'offer assessment': 6,
#  'wmd related': 6,
#  'bin ladins': 6,
#  'operational capabilities': 6,
#  'nuclear materials': 6,
#  'interests worldwide': 6,
#  'capable conducting': 6,
#  'scale attacks': 6,
#  'interests abroad': 6,
#  'near east': 6,
#  'islamic extremists': 6,
#  'continue exploit': 6,
#  'suicide attacks': 6,
#  'improvised explosive': 6,
#  'throughout country': 6,
#  'electric power': 6,
#  'foreign aid': 6,
#  'afghan leaders': 6,
#  'geographic scope': 6,
#  'depend heavily': 6,
#  'safety nation': 6,
#  'constraints may': 6,
#  'utility preventing': 6,
#  'many years': 6,
#  'use move': 6,
#  'weapons assess': 6,
#  'assess countries': 6,
#  'programs continue': 6,
#  'iran seeks': 6,
#  'iran already': 6,
#  'tehran views': 6,
#  'part strategy': 6,
#  'necessary retaliate': 6,
#  'including forces': 6,
#  'threatening instability': 6,
#  'financial resources': 6,
#  'project military': 6,
#  'israeli palestinian': 6,
#  'attacks interests': 6,
#  'africa asia': 6,
#  'political military': 6,
#  'presidential legislative': 6,
#  'major source': 6,
#  'building measures': 6,
#  'ties iran': 6,
#  'continue deteriorate': 6,
#  'worlds largest': 6,
#  'five year': 6,
#  'sudan nigeria': 6,
#  'national unity': 6,
#  'ethno religious': 6,
#  'criminal networks': 6,
#  'political influence': 6,
#  'improve governance': 6,
#  'technical capabilities': 6,
#  'energy markets': 6,
#  'millions people': 6,
#  'greatest threat': 6,
#  'attacks homeland': 6,
#  'foreign governments': 6,
#  'ansar al': 6,
#  'positive developments': 6,
#  'electrical power': 6,
#  'iraq aqi': 6,
#  'across borders': 6,
#  'country faces': 6,
#  'islamic extremism': 6,
#  'become even': 6,
#  'use technologies': 6,
#  'iranian nuclear': 6,
#  'power influence': 6,
#  'lesser extent': 6,
#  'challenges interests': 6,
#  'hizballah hamas': 6,
#  'lebanon lebanon': 6,
#  'palestinian territories': 6,
#  'horn africa': 6,
#  'million internally': 6,
#  'transitional federal': 6,
#  'southern somalia': 6,
#  'major powers': 6,
#  'medium range': 6,
#  'financial system': 6,
#  'exchange reserves': 6,
#  'based militants': 6,
#  'concerned potential': 6,
#  'russia russia': 6,
#  'domestic foreign': 6,
#  'political situation': 6,
#  'atlantic integration': 6,
#  'military advantages': 6,
#  'continues pursue': 6,
#  'nuclear capable': 6,
#  'could threaten': 6,
#  'qaida affiliates': 6,
#  'usama bin': 6,
#  'ayman al': 6,
#  'al zawahiri': 6,
#  'significant economic': 6,
#  'significant damage': 6,
#  'related activities': 6,
#  'range missiles': 6,
#  'use nuclear': 6,
#  'iran scientific': 6,
#  'technical industrial': 6,
#  'industrial capacity': 6,
#  'capacity eventually': 6,
#  'eventually produce': 6,
#  'iran made': 6,
#  'still faces': 6,
#  'enrichment capability': 6,
#  'attempt use': 6,
#  'nuclear facilities': 6,
#  'virtually every': 6,
#  'including russia': 6,
#  'taliban dominated': 6,
#  'dominated insurgency': 6,
#  'governments ability': 6,
#  'economic opportunity': 6,
#  'operational tempo': 6,
#  'approximately percent': 6,
#  'government authority': 6,
#  'record levels': 6,
#  'influence iraq': 6,
#  'lethal aid': 6,
#  'take place': 6,
#  'according press': 6,
#  'ship cruise': 6,
#  'resistance israel': 6,
#  'coalition government': 6,
#  'syrian opposition': 6,
#  'political developments': 6,
#  'remain vulnerable': 6,
#  'line contact': 6,
#  'northern kosovo': 6,
#  'likely slow': 6,
#  'liberation army': 6,
#  'missile capabilities': 6,
#  'countries particularly': 6,
#  'raising risk': 6,
#  'colombia farc': 6,
#  'parts africa': 6,
#  'darfur region': 6,
#  'north south': 6,
#  'counterinsurgency operations': 6,
#  'political uncertainty': 6,
#  'gulf oil': 6,
#  'oil facilities': 6,
#  'political violence': 6,
#  'billions dollars': 6,
#  'estimated billion': 6,
#  'oil companies': 6,
#  'past five': 6,
#  'would likely': 6,
#  'economic financial': 6,
#  'foreign direct': 6,
#  'economic problems': 6,
#  'since fall': 6,
#  'operating environment': 6,
#  'based al': 6,
#  'european governments': 6,
#  'western targets': 6,
#  'use military': 6,
#  'iran continue': 6,
#  'sectarian violence': 6,
#  'within syria': 6,
#  'improve relations': 6,
#  'armed conflict': 6,
#  'parts country': 6,
#  'opium prices': 6,
#  'terrorist insurgent': 6,
#  'low enriched': 6,
#  'whether iran': 6,
#  'domestic priorities': 6,
#  'past several': 6,
#  'political support': 6,
#  'international prestige': 6,
#  'missiles associated': 6,
#  'associated materials': 6,
#  'nuclear technology': 6,
#  'economic downturn': 6,
#  'foreign military': 6,
#  'pose greatest': 6,
#  'growth rate': 6,
#  ...}

# %%
plt.figure(figsize = (20,20)) # Text that is not Fake
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800 , stopwords = STOPWORDS).fit_words(most_common_bi)
plt.imshow(wc , interpolation = 'bilinear')
plt.savefig('worldAll2', dpi=600)
plt.show()

# %%
#Para fazer tokenização

df['token'] = df.text_b.map(word_tokenize)

# %%
df
# Out:
#                                                    text  \
# 2006        Annual Threat Assessment of the Director...
# 2007    \n Annual Threat Assessment \nof the \nDirec...
# 2008       Annual Threat Assessment of the   Intelli...
# 2009       Annual Threat Assessment of the   Intelli...
# 2010      Annual Threat Assessment of the   US Intel...
# 2011
# 2012   \n \n \n \n \nUnclassified Statement for the ...
# 2013     Statement for the Record  \n Worldwide Thre...
# 2014   \n \n \nStatement for the Record \n \n \nWorl...
# 2015   \n \nStatement for the Record \n \n \nWorldwi...
# 2016   \nStatement for the Record \n \n \nWorldwide ...
# 2017   \n \nStatement for the Record \n \n \nWorldwi...
# 2018   \n1\n \n \n \n6 March 2018\n \n \n \n  \n2\n ...
# 2019     29 JANUARY\n 2019 Senate Select Committee o...
#
#                                                  text_b  \
# 2006  annual threat assessment of the director of na...
# 2007  annual threat assessment of the director of na...
# 2008  annual threat assessment of the   intelligence...
# 2009  annual threat assessment of the   intelligence...
# 2010  annual threat assessment of the   us intellige...
# 2011
# 2012  unclassified statement for the record on the  ...
# 2013  statement for the record  worldwide threat ass...
# 2014  statement for the record  worldwide threat ass...
# 2015  statement for the record  worldwide threat ass...
# 2016  statement for the record  worldwide threat ass...
# 2017  statement for the record  worldwide threat ass...
# 2018  march      statement for the record  worldwide...
# 2019  january   senate select committee on intellige...
#
#                                                   token
# 2006  [annual, threat, assessment, of, the, director...
# 2007  [annual, threat, assessment, of, the, director...
# 2008  [annual, threat, assessment, of, the, intellig...
# 2009  [annual, threat, assessment, of, the, intellig...
# 2010  [annual, threat, assessment, of, the, us, inte...
# 2011                                                 []
# 2012  [unclassified, statement, for, the, record, on...
# 2013  [statement, for, the, record, worldwide, threa...
# 2014  [statement, for, the, record, worldwide, threa...
# 2015  [statement, for, the, record, worldwide, threa...
# 2016  [statement, for, the, record, worldwide, threa...
# 2017  [statement, for, the, record, worldwide, threa...
# 2018  [march, statement, for, the, record, worldwide...
# 2019  [january, senate, select, committee, on, intel...

# %%
stop_lambda = lambda x: [y for y in x if y not in stop]
#aplica a função na coluna dos tokens
df['tokens_stop'] = df.token.apply(stop_lambda)
df.head()
# Out:
#                                                    text  \
# 2006        Annual Threat Assessment of the Director...
# 2007    \n Annual Threat Assessment \nof the \nDirec...
# 2008       Annual Threat Assessment of the   Intelli...
# 2009       Annual Threat Assessment of the   Intelli...
# 2010      Annual Threat Assessment of the   US Intel...
#
#                                                  text_b  \
# 2006  annual threat assessment of the director of na...
# 2007  annual threat assessment of the director of na...
# 2008  annual threat assessment of the   intelligence...
# 2009  annual threat assessment of the   intelligence...
# 2010  annual threat assessment of the   us intellige...
#
#                                                   token  \
# 2006  [annual, threat, assessment, of, the, director...
# 2007  [annual, threat, assessment, of, the, director...
# 2008  [annual, threat, assessment, of, the, intellig...
# 2009  [annual, threat, assessment, of, the, intellig...
# 2010  [annual, threat, assessment, of, the, us, inte...
#
#                                             tokens_stop
# 2006  [annual, threat, assessment, director, nationa...
# 2007  [annual, threat, assessment, director, nationa...
# 2008  [annual, threat, assessment, intelligence, com...
# 2009  [annual, threat, assessment, intelligence, com...
# 2010  [annual, threat, assessment, intelligence, com...

# %%
# partes de speech tagging
from nltk.tag import pos_tag
nltk.download('averaged_perceptron_tagger')
pos_lambda = lambda x: nltk.pos_tag(x)
df['tokens_pos'] = (df.tokens_stop.apply(pos_lambda))
df.head()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
#                                                    text  \
# 2006        Annual Threat Assessment of the Director...
# 2007    \n Annual Threat Assessment \nof the \nDirec...
# 2008       Annual Threat Assessment of the   Intelli...
# 2009       Annual Threat Assessment of the   Intelli...
# 2010      Annual Threat Assessment of the   US Intel...
#
#                                                  text_b  \
# 2006  annual threat assessment of the director of na...
# 2007  annual threat assessment of the director of na...
# 2008  annual threat assessment of the   intelligence...
# 2009  annual threat assessment of the   intelligence...
# 2010  annual threat assessment of the   us intellige...
#
#                                                   token  \
# 2006  [annual, threat, assessment, of, the, director...
# 2007  [annual, threat, assessment, of, the, director...
# 2008  [annual, threat, assessment, of, the, intellig...
# 2009  [annual, threat, assessment, of, the, intellig...
# 2010  [annual, threat, assessment, of, the, us, inte...
#
#                                             tokens_stop  \
# 2006  [annual, threat, assessment, director, nationa...
# 2007  [annual, threat, assessment, director, nationa...
# 2008  [annual, threat, assessment, intelligence, com...
# 2009  [annual, threat, assessment, intelligence, com...
# 2010  [annual, threat, assessment, intelligence, com...
#
#                                              tokens_pos
# 2006  [(annual, JJ), (threat, NN), (assessment, JJ),...
# 2007  [(annual, JJ), (threat, NN), (assessment, JJ),...
# 2008  [(annual, JJ), (threat, NN), (assessment, JJ),...
# 2009  [(annual, JJ), (threat, NN), (assessment, JJ),...
# 2010  [(annual, JJ), (threat, NN), (assessment, JJ),...

# %%
# Realizar lematização, que é uma forma mais inteligente de derivação e leva em consideração o contexto
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('averaged_perceptron_tagger')
nltk.download('all')

# Convert the naming scheme to one that is recognized by WordNet
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

lemmatizer = WordNetLemmatizer()
lemmatizer_fun = lambda x: lemmatizer.lemmatize(*x)
df['tokens_lemma'] = df.tokens_pos\
                        .apply(lambda x: [(y[0], get_wordnet_pos(y[1])) for y in x])\
                        .apply(lambda x: [lemmatizer_fun(y) for y in x])
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-08ea5be25533> in <module>
#      25
#      26 # Exibir as colunas transpostas
# ---> 27 data.head().T
#
# NameError: name 'data' is not defined

# %%
df.head().T
# Out:
#                                                            2006  \
# text                Annual Threat Assessment of the Director...
# text_b        annual threat assessment of the director of na...
# token         [annual, threat, assessment, of, the, director...
# tokens_stop   [annual, threat, assessment, director, nationa...
# tokens_pos    [(annual, JJ), (threat, NN), (assessment, JJ),...
# tokens_lemma  [annual, threat, assessment, director, nationa...
#
#                                                            2007  \
# text            \n Annual Threat Assessment \nof the \nDirec...
# text_b        annual threat assessment of the director of na...
# token         [annual, threat, assessment, of, the, director...
# tokens_stop   [annual, threat, assessment, director, nationa...
# tokens_pos    [(annual, JJ), (threat, NN), (assessment, JJ),...
# tokens_lemma  [annual, threat, assessment, director, nationa...
#
#                                                            2008  \
# text               Annual Threat Assessment of the   Intelli...
# text_b        annual threat assessment of the   intelligence...
# token         [annual, threat, assessment, of, the, intellig...
# tokens_stop   [annual, threat, assessment, intelligence, com...
# tokens_pos    [(annual, JJ), (threat, NN), (assessment, JJ),...
# tokens_lemma  [annual, threat, assessment, intelligence, com...
#
#                                                            2009  \
# text               Annual Threat Assessment of the   Intelli...
# text_b        annual threat assessment of the   intelligence...
# token         [annual, threat, assessment, of, the, intellig...
# tokens_stop   [annual, threat, assessment, intelligence, com...
# tokens_pos    [(annual, JJ), (threat, NN), (assessment, JJ),...
# tokens_lemma  [annual, threat, assessment, intelligence, com...
#
#                                                            2010
# text              Annual Threat Assessment of the   US Intel...
# text_b        annual threat assessment of the   us intellige...
# token         [annual, threat, assessment, of, the, us, inte...
# tokens_stop   [annual, threat, assessment, intelligence, com...
# tokens_pos    [(annual, JJ), (threat, NN), (assessment, JJ),...
# tokens_lemma  [annual, threat, assessment, intelligence, com...

# %% [markdown]
# ### Adiciona Bi-Grams ede todas as linhas

# %%
di = {}

for x in df.index:
    g = []
    for gram in ngrams(df['tokens_lemma'][x],2): 
        g.append(' '.join(gram))
    di[x] = g

# %%
df['bi_gram'] = di.values()

# %%
df.head()
# Out:
#                                                    text  \
# 2006        Annual Threat Assessment of the Director...
# 2007    \n Annual Threat Assessment \nof the \nDirec...
# 2008       Annual Threat Assessment of the   Intelli...
# 2009       Annual Threat Assessment of the   Intelli...
# 2010      Annual Threat Assessment of the   US Intel...
#
#                                                  text_b  \
# 2006  annual threat assessment of the director of na...
# 2007  annual threat assessment of the director of na...
# 2008  annual threat assessment of the   intelligence...
# 2009  annual threat assessment of the   intelligence...
# 2010  annual threat assessment of the   us intellige...
#
#                                                   token  \
# 2006  [annual, threat, assessment, of, the, director...
# 2007  [annual, threat, assessment, of, the, director...
# 2008  [annual, threat, assessment, of, the, intellig...
# 2009  [annual, threat, assessment, of, the, intellig...
# 2010  [annual, threat, assessment, of, the, us, inte...
#
#                                             tokens_stop  \
# 2006  [annual, threat, assessment, director, nationa...
# 2007  [annual, threat, assessment, director, nationa...
# 2008  [annual, threat, assessment, intelligence, com...
# 2009  [annual, threat, assessment, intelligence, com...
# 2010  [annual, threat, assessment, intelligence, com...
#
#                                              tokens_pos  \
# 2006  [(annual, JJ), (threat, NN), (assessment, JJ),...
# 2007  [(annual, JJ), (threat, NN), (assessment, JJ),...
# 2008  [(annual, JJ), (threat, NN), (assessment, JJ),...
# 2009  [(annual, JJ), (threat, NN), (assessment, JJ),...
# 2010  [(annual, JJ), (threat, NN), (assessment, JJ),...
#
#                                            tokens_lemma  \
# 2006  [annual, threat, assessment, director, nationa...
# 2007  [annual, threat, assessment, director, nationa...
# 2008  [annual, threat, assessment, intelligence, com...
# 2009  [annual, threat, assessment, intelligence, com...
# 2010  [annual, threat, assessment, intelligence, com...
#
#                                                 bi_gram
# 2006  [annual threat, threat assessment, assessment ...
# 2007  [annual threat, threat assessment, assessment ...
# 2008  [annual threat, threat assessment, assessment ...
# 2009  [annual threat, threat assessment, assessment ...
# 2010  [annual threat, threat assessment, assessment ...

# %% [markdown]
# ### Adiciona Tri-Grams ede todas as linhas

# %%
di = {}

for x in df.index:
    g = []
    for gram in ngrams(df['tokens_lemma'][x],3): 
        g.append(' '.join(gram))
    di[x] = g

# %%
df['tri_gram'] = di.values()

# %%
df.head()
# Out:
#                                                    text  \
# 2006        Annual Threat Assessment of the Director...
# 2007    \n Annual Threat Assessment \nof the \nDirec...
# 2008       Annual Threat Assessment of the   Intelli...
# 2009       Annual Threat Assessment of the   Intelli...
# 2010      Annual Threat Assessment of the   US Intel...
#
#                                                  text_b  \
# 2006  annual threat assessment of the director of na...
# 2007  annual threat assessment of the director of na...
# 2008  annual threat assessment of the   intelligence...
# 2009  annual threat assessment of the   intelligence...
# 2010  annual threat assessment of the   us intellige...
#
#                                                   token  \
# 2006  [annual, threat, assessment, of, the, director...
# 2007  [annual, threat, assessment, of, the, director...
# 2008  [annual, threat, assessment, of, the, intellig...
# 2009  [annual, threat, assessment, of, the, intellig...
# 2010  [annual, threat, assessment, of, the, us, inte...
#
#                                             tokens_stop  \
# 2006  [annual, threat, assessment, director, nationa...
# 2007  [annual, threat, assessment, director, nationa...
# 2008  [annual, threat, assessment, intelligence, com...
# 2009  [annual, threat, assessment, intelligence, com...
# 2010  [annual, threat, assessment, intelligence, com...
#
#                                              tokens_pos  \
# 2006  [(annual, JJ), (threat, NN), (assessment, JJ),...
# 2007  [(annual, JJ), (threat, NN), (assessment, JJ),...
# 2008  [(annual, JJ), (threat, NN), (assessment, JJ),...
# 2009  [(annual, JJ), (threat, NN), (assessment, JJ),...
# 2010  [(annual, JJ), (threat, NN), (assessment, JJ),...
#
#                                            tokens_lemma  \
# 2006  [annual, threat, assessment, director, nationa...
# 2007  [annual, threat, assessment, director, nationa...
# 2008  [annual, threat, assessment, intelligence, com...
# 2009  [annual, threat, assessment, intelligence, com...
# 2010  [annual, threat, assessment, intelligence, com...
#
#                                                 bi_gram  \
# 2006  [annual threat, threat assessment, assessment ...
# 2007  [annual threat, threat assessment, assessment ...
# 2008  [annual threat, threat assessment, assessment ...
# 2009  [annual threat, threat assessment, assessment ...
# 2010  [annual threat, threat assessment, assessment ...
#
#                                                tri_gram
# 2006  [annual threat assessment, threat assessment d...
# 2007  [annual threat assessment, threat assessment d...
# 2008  [annual threat assessment, threat assessment i...
# 2009  [annual threat assessment, threat assessment i...
# 2010  [annual threat assessment, threat assessment i...

# %% [markdown]
# Aqui termina os tratamentos anuais.
# <br>
# ------------------------------------
#    #### A partir daqui começa a análise de cada ano separadamente

# %% [markdown]
# Análises de 1 palavra

# %%
def analise_ano_x(df, ano, gerar_wordcloud = 0):
    '''
    df -> dataframe onde está o texto tratado
    ano -> STRING com o ano que se deseja analisar. No momento está disponível de 2006 a 2019, com exceção de 2011
    '''
    # Converte a lista em um dicionário com contagem de valores
    word_counts = Counter(df['tokens_stop'][ano])
    b = word_counts
    a = word_counts
    

    # Inverter a chave / valores no dicionário para classificarReverter a chave / valores no dicionário para classificar
    word_counts = list(zip(word_counts.values(), word_counts.keys()))

    # Classifique a lista por contagem
    word_counts = sorted(word_counts, reverse=True)

    # Imprime as 20 palavras mais comuns
    print(word_counts[:20])
    
    
    #Fazendo relatório
    b = list(zip(b.keys(), b.values()))
    b = sorted(b, reverse=True, key = lambda x: x[1])
    relatorio = pd.DataFrame(data = dict(b).values(), index = dict(b).keys(), columns = ['quantidade'])
    total_de_palavras = relatorio.quantidade.sum()
    porcentagem = relatorio.quantidade / relatorio.quantidade.sum()
    print(relatorio.head())
    print('---------')
    print(porcentagem.head())
    result = pd.concat([relatorio, porcentagem.to_frame('porcentagem')], axis=1, sort=False)
    
    if gerar_wordcloud == 1:
        nome = 'wordcloud'+ano+'.png'    
        wordcloud = WordCloud(width=1600, height=800, max_font_size=200).fit_words(a) # o 'a' veio de um counter
        plt.figure(figsize=(16,13))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis("off")
        plt.savefig(nome, dpi=600)
        plt.show()
    
    return result

# %%
d2006 = analise_ano_x(df, '2006')
d2007 = analise_ano_x(df, '2007')
d2008 = analise_ano_x(df, '2008')
d2009 = analise_ano_x(df, '2009')
d2010 = analise_ano_x(df, '2010')
#d2011 = analise_ano_x(df, '2011')
d2012 = analise_ano_x(df, '2012')
d2013 = analise_ano_x(df, '2013')
d2014 = analise_ano_x(df, '2014')
d2015 = analise_ano_x(df, '2015')
d2016 = analise_ano_x(df, '2016')
d2017 = analise_ano_x(df, '2017')
d2018 = analise_ano_x(df, '2018')
d2019 = analise_ano_x(df, '2019')
# Out:
# [(38, 'political'), (31, 'intelligence'), (31, 'al'), (30, 'economic'), (24, 'iraq'), (24, 'global'), (23, 'weapons'), (23, 'government'), (22, 'threat'), (22, 'groups'), (21, 'security'), (21, 'iran'), (20, 'new'), (18, 'world'), (18, 'qaida'), (18, 'nuclear'), (18, 'interests'), (17, 'sunni'), (16, 'national'), (16, 'forces')]
#               quantidade
# political             38
# intelligence          31
# al                    31
# economic              30
# global                24
# ---------
# political       0.007652
# intelligence    0.006242
# al              0.006242
# economic        0.006041
# global          0.004833
# Name: quantidade, dtype: float64
# [(24, 'region'), (22, 'security'), (20, 'political'), (20, 'al'), (19, 'national'), (19, 'iraq'), (19, 'government'), (17, 'intelligence'), (16, 'year'), (15, 'power'), (15, 'nuclear'), (15, 'energy'), (15, 'countries'), (14, 'terrorist'), (14, 'major'), (14, 'last'), (13, 'pakistan'), (13, 'economic'), (13, 'continue'), (12, 'threat')]
#            quantidade
# region             24
# security           22
# al                 20
# political          20
# national           19
# ---------
# region       0.006405
# security     0.005871
# al           0.005338
# political    0.005338
# national     0.005071
# Name: quantidade, dtype: float64
# [(74, 'security'), (64, 'al'), (60, 'nuclear'), (55, 'political'), (49, 'statement'), (49, 'record'), (48, 'government'), (45, 'iran'), (45, 'continue'), (44, 'weapons'), (44, 'sasc'), (44, 'feb'), (44, 'ata'), (43, 'qaida'), (40, 'forces'), (39, 'economic'), (37, 'year'), (36, 'threat'), (36, 'iraq'), (35, 'military')]
#            quantidade
# security           74
# al                 64
# nuclear            60
# political          55
# statement          49
# ---------
# security     0.007882
# al           0.006816
# nuclear      0.006390
# political    0.005858
# statement    0.005219
# Name: quantidade, dtype: float64
# [(99, 'economic'), (78, 'security'), (76, 'al'), (69, 'political'), (66, 'government'), (63, 'nuclear'), (58, 'military'), (54, 'groups'), (53, 'global'), (52, 'record'), (52, 'iran'), (50, 'support'), (50, 'leaders'), (48, 'weapons'), (47, 'statement'), (47, 'countries'), (46, 'qaida'), (45, 'feb'), (45, 'could'), (45, 'attacks')]
#             quantidade
# economic            99
# security            78
# al                  76
# political           69
# government          66
# ---------
# economic      0.007171
# security      0.005650
# al            0.005505
# political     0.004998
# government    0.004781
# Name: quantidade, dtype: float64
# [(93, 'economic'), (83, 'al'), (68, 'government'), (66, 'security'), (65, 'international'), (64, 'political'), (59, 'qaida'), (56, 'statement'), (53, 'continue'), (51, 'record'), (51, 'efforts'), (50, 'groups'), (49, 'year'), (48, 'support'), (48, 'countries'), (47, 'intelligence'), (46, 'nuclear'), (46, 'feb'), (46, 'ata'), (45, 'threat')]
#                quantidade
# economic               93
# al                     83
# government             68
# security               66
# international          65
# ---------
# economic         0.007041
# al               0.006284
# government       0.005148
# security         0.004997
# international    0.004921
# Name: quantidade, dtype: float64
# [(50, 'security'), (50, 'al'), (48, 'political'), (39, 'economic'), (37, 'government'), (32, 'nuclear'), (32, 'global'), (29, 'assess'), (27, 'year'), (26, 'water'), (25, 'military'), (25, 'forces'), (24, 'oil'), (24, 'iran'), (24, 'attacks'), (23, 'national'), (23, 'likely'), (23, 'however'), (22, 'threat'), (22, 'percent')]
#             quantidade
# security            50
# al                  50
# political           48
# economic            39
# government          37
# ---------
# security      0.006800
# al            0.006800
# political     0.006528
# economic      0.005304
# government    0.005032
# Name: quantidade, dtype: float64
# [(58, 'security'), (57, 'economic'), (53, 'political'), (50, 'government'), (47, 'military'), (36, 'foreign'), (33, 'year'), (33, 'north'), (32, 'countries'), (31, 'however'), (31, 'forces'), (30, 'iran'), (29, 'nuclear'), (29, 'national'), (28, 'intelligence'), (28, 'continue'), (28, 'attacks'), (27, 'water'), (27, 'threat'), (27, 'since')]
#             quantidade
# security            58
# economic            57
# political           53
# government          50
# military            47
# ---------
# security      0.006130
# economic      0.006024
# political     0.005601
# government    0.005284
# military      0.004967
# Name: quantidade, dtype: float64
# [(52, 'economic'), (51, 'security'), (51, 'continue'), (43, 'government'), (40, 'political'), (35, 'probably'), (31, 'global'), (30, 'military'), (30, 'countries'), (29, 'threat'), (28, 'iran'), (27, 'threats'), (27, 'might'), (27, 'central'), (26, 'new'), (26, 'likely'), (25, 'water'), (25, 'support'), (25, 'north'), (25, 'however')]
#             quantidade
# economic            52
# security            51
# continue            51
# government          43
# political           40
# ---------
# economic      0.006621
# security      0.006494
# continue      0.006494
# government    0.005475
# political     0.005093
# Name: quantidade, dtype: float64
# [(51, 'security'), (50, 'probably'), (50, 'economic'), (42, 'cyber'), (31, 'government'), (30, 'international'), (28, 'continue'), (27, 'threat'), (27, 'global'), (26, 'political'), (25, 'forces'), (25, 'countries'), (24, 'russia'), (24, 'north'), (23, 'remain'), (23, 'attacks'), (21, 'state'), (21, 'isil'), (21, 'including'), (21, 'capabilities')]
#             quantidade
# security            51
# economic            50
# probably            50
# cyber               42
# government          31
# ---------
# security      0.008254
# economic      0.008092
# probably      0.008092
# cyber         0.006797
# government    0.005017
# Name: quantidade, dtype: float64
# [(60, 'continue'), (54, 'probably'), (48, 'security'), (41, 'threat'), (38, 'political'), (37, 'economic'), (36, 'isil'), (34, 'remain'), (33, 'government'), (32, 'groups'), (31, 'might'), (30, 'russia'), (28, 'military'), (27, 'use'), (27, 'syria'), (27, 'attacks'), (26, 'terrorist'), (26, 'intelligence'), (25, 'countries'), (24, 'systems')]
#            quantidade
# continue           60
# probably           54
# security           48
# threat             41
# political          38
# ---------
# continue     0.007719
# probably     0.006947
# security     0.006175
# threat       0.005275
# political    0.004889
# Name: quantidade, dtype: float64
# [(70, 'continue'), (54, 'threat'), (44, 'likely'), (43, 'cyber'), (41, 'security'), (40, 'global'), (39, 'military'), (39, 'economic'), (38, 'russia'), (36, 'attacks'), (33, 'countries'), (32, 'support'), (30, 'remain'), (30, 'probably'), (30, 'isis'), (30, 'china'), (29, 'state'), (29, 'capabilities'), (28, 'weapons'), (28, 'syria')]
#           quantidade
# continue          70
# threat            54
# likely            44
# cyber             43
# security          41
# ---------
# continue    0.009560
# threat      0.007375
# likely      0.006009
# cyber       0.005873
# security    0.005600
# Name: quantidade, dtype: float64
# [(57, 'continue'), (39, 'attacks'), (37, 'russia'), (37, 'cyber'), (36, 'likely'), (35, 'probably'), (34, 'security'), (34, 'economic'), (31, 'threat'), (31, 'iran'), (30, 'countries'), (28, 'isis'), (28, 'china'), (27, 'political'), (26, 'use'), (26, 'including'), (25, 'interests'), (24, 'weapons'), (24, 'operations'), (22, 'foreign')]
#           quantidade
# continue          57
# attacks           39
# cyber             37
# russia            37
# likely            36
# ---------
# continue    0.009884
# attacks     0.006763
# cyber       0.006416
# russia      0.006416
# likely      0.006242
# Name: quantidade, dtype: float64
# [(59, 'military'), (57, 'china'), (56, 'economic'), (48, 'russia'), (47, 'continue'), (45, 'influence'), (44, 'security'), (43, 'cyber'), (37, 'iran'), (34, 'political'), (33, 'capabilities'), (32, 'likely'), (31, 'use'), (30, 'threat'), (30, 'global'), (30, 'countries'), (30, 'assess'), (29, 'weapons'), (29, 'nuclear'), (28, 'attacks')]
#           quantidade
# military          59
# china             57
# economic          56
# russia            48
# continue          47
# ---------
# military    0.007690
# china       0.007430
# economic    0.007299
# russia      0.006257
# continue    0.006126
# Name: quantidade, dtype: float64

# %% [markdown]
# Ta ok. Fazer isso por ano e uma linha do tempo

# %% [markdown]
# # ATÉ AQUI

# %%
plt.figure(figsize = (16,9))
most_common_uni = get_top_text_ngrams(df.text_b,20,1)
most_common_uni = dict(most_common_uni)
sns.barplot(x=list(most_common_uni.values()),y=list(most_common_uni.keys()))

# %%
most_common_uni
# Out:
# {'economic': 623,
#  'security': 618,
#  'political': 528,
#  'continue': 507,
#  'government': 468,
#  'al': 447,
#  'also': 415,
#  'threat': 414,
#  'military': 407,
#  'iran': 385,
#  'nuclear': 385,
#  'countries': 365,
#  'global': 361,
#  'groups': 346,
#  'attacks': 343,
#  'probably': 337,
#  'weapons': 304,
#  'intelligence': 302,
#  'remain': 299,
#  'international': 299}

# %%
plt.figure(figsize = (16,9))
most_common_uni = get_top_text_ngrams(df.text_b,15,2)
most_common_uni = dict(most_common_uni)
sns.barplot(x=list(most_common_uni.values()),y=list(most_common_uni.keys()))

# %%
plt.figure(figsize = (16,9))
most_common_uni = get_top_text_ngrams(df.text_b,15,3)
most_common_uni = dict(most_common_uni)
sns.barplot(x=list(most_common_uni.values()),y=list(most_common_uni.keys()))

# %%
z = get_top_text_ngrams(a.pagina,25,3)
z
# Out:
# [('adversaries strategic competitors', 11),
#  ('united states allies', 9),
#  ('online influence operations', 6),
#  ('influence operations election', 4),
#  ('operations election interference', 4),
#  ('cyber espionage attack', 4),
#  ('threats us national', 3),
#  ('us national security', 3),
#  ('weapons mass destruction', 3),
#  ('global economic growth', 3),
#  ('espionage attack influence', 3),
#  ('election interference section', 3),
#  ('localized temporary disruptive', 3),
#  ('target us allied', 3),
#  ('us adversaries strategic', 3),
#  ('past two years', 3),
#  ('russian president vladimir', 3),
#  ('president vladimir putin', 3),
#  ('including united states', 3),
#  ('violent ethno supremacist', 3),
#  ('south china sea', 3),
#  ('kim jong un', 3),
#  ('saudi arabia uae', 3),
#  ('mass destruction proliferation', 2),
#  ('regional threats china', 2)]

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(width=1600, height=800, max_font_size=200).fit_words(most_common_uni) # o 'a' veio de um counter
#wordcloud = WordCloud(width=1600, height=800, max_font_size=200).generate(text)
plt.figure(figsize=(16,13))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
#plt.savefig('wordcloud.png', dpi=600)
plt.show()

# %%
#Para fazer tokenização
from nltk.tokenize import word_tokenize
a['token'] = a.pagina.map(word_tokenize)

# %%
a = pd.DataFrame(ab, columns = ['pagina'])

# %%
a
# Out:
#                                                pagina
# 0        january    senate select committee on int...
# 1     statement for the record     worldwide threa...
# 2     contents  introduction                      ...
# 3      foreword  threats to us national security w...
# 4      global t hre ats  cyber  our adversaries  a...
# 5       russian intelligence and security services...
# 6      the growing availability and use of publicl...
# 7      weapons of  mass destruction an d prolifera...
# 8          promised not to make test use or  proli...
# 9      iran  we continue to assess that iran is no...
# 10      global jihadist groups in parts of africa ...
# 11     al  al  ing to encourage attacks against th...
# 12     lebanese hizballah  during  the next year h...
# 13     intelligence services and other entities su...
# 14     emerging and disrupt ive technologies and  ...
# 15     privacy challenges   furthermore  interacti...
# 16      global access to space services has  expan...
# 17     transnational organi zed crime  global tran...
# 18     transnational organized crime almost certai...
# 19     nationwide protests that forced the prime m...
# 20       reflecting tariffs sanctions on the russi...
# 21      human displacement  global displacement al...
# 22     environm ent and climate change  global env...
# 23     regional threats  china and russia  china a...
# 24      president xi removed one of the few remain...
# 25      beijing has stepped up efforts to reshape ...
# 26     north korea  nuclear ambitions  pyongyang h...
# 27     and rail lines establish new military param...
# 28      russia too has been increasing its diploma...
# 29     positions in syria    we assess  that  iran...
# 30      we assess that unprofessional interactions...
# 31     iraqi shia militants conducted several atta...
# 32      yemen  the huthi movement in yemen and the...
# 33      the humanitarian impacts of the conflict i...
# 34     south asia  the challenges facing south asi...
# 35     russia and eurasia  russian president vladi...
# 36     global ambitions   commercial and energy f ...
# 37      in   we assess  that  russia will continue...
# 38     national leaders  to contend with increased...
# 39     and its extremist allies present a  growing...
# 40     bolivia el salvador guatemala panama and ur...
# 41     venezuela  although  the regime of  nicolas...

# %%
a['token'] = a.pagina.map(word_tokenize)

# %%
a.head()
# Out:
#                                               pagina  \
# 0       january    senate select committee on int...
# 1    statement for the record     worldwide threa...
# 2    contents  introduction                      ...
# 3     foreword  threats to us national security w...
# 4     global t hre ats  cyber  our adversaries  a...
#
#                                                token
# 0  [january, senate, select, committee, on, intel...
# 1  [statement, for, the, record, worldwide, threa...
# 2  [contents, introduction, contents, foreword, g...
# 3  [foreword, threats, to, us, national, security...
# 4  [global, t, hre, ats, cyber, our, adversaries,...

# %%
# Isso cria uma lista enorme combinando todos os valores de tokens
word_list = sum(a.token.tolist(), [])

word_list[:10]
# Out:
# ['january',
#  'senate',
#  'select',
#  'committee',
#  'on',
#  'intelligence',
#  'statement',
#  'for',
#  'the',
#  'record']

# %%
# Estas são as etapas para encontrar as palavras mais comuns

from collections import Counter

# Converte a lista em um dicionário com contagem de valores
word_counts = Counter(word_list)

# Inverter a chave / valores no dicionário para classificarReverter a chave / valores no dicionário para classificar
word_counts = list(zip(word_counts.values(), word_counts.keys()))

# Classifique a lista por contagem
word_counts = sorted(word_counts, reverse=True)

# Imprime as 10 palavras mais comuns
word_counts[:10]
# Out:
# [(710, 'and'),
#  (537, 'the'),
#  (494, 'to'),
#  (310, 'in'),
#  (289, 'of'),
#  (152, 'a'),
#  (131, 'will'),
#  (116, 'us'),
#  (102, 'as'),
#  (99, 'that')]

# %%
# A distribuição dos comprimentos das palavras
word_lengths = pd.Series([len(x) for x in word_list])

ax = word_lengths.hist(bins=15)
ax.set(xlabel='Word Lengths', ylabel='Frequency', title='Distribution of Word Length');

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words_en = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\galag\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Para aplicar essa limpeza ao corpus
clean_words = [word for word in word_list if not (word in stop_words_en)]

# %%
clean_words
# Out:
# ['january',
#  'senate',
#  'select',
#  'committee',
#  'intelligence',
#  'statement',
#  'record',
#  'worldwide',
#  'threat',
#  'assessment',
#  'us',
#  'intelligence',
#  'community',
#  'january',
#  'introduction',
#  'chairman',
#  'burr',
#  'vice',
#  'chairman',
#  'warner',
#  'members',
#  'committee',
#  'thank',
#  'invitation',
#  'assessment',
#  'threats',
#  'us',
#  'national',
#  'security',
#  'en',
#  'men',
#  'privileged',
#  'honored',
#  'lead',
#  'intelligence',
#  'community',
#  'committed',
#  'every',
#  'day',
#  'providing',
#  'nuanced',
#  'independent',
#  'unvarnished',
#  'intelligence',
#  'policymakers',
#  'warfighters',
#  'domestic',
#  'law',
#  'enforcement',
#  'personnel',
#  'need',
#  'protect',
#  'american',
#  'lives',
#  'order',
#  'topics',
#  'presented',
#  'statement',
#  'necessarily',
#  'indicate',
#  'relative',
#  'importance',
#  'magnitude',
#  'threat',
#  'view',
#  'intelligence',
#  'community',
#  'informa',
#  'tion',
#  'available',
#  'jan',
#  'uary',
#  'used',
#  'preparation',
#  'assessment',
#  'attention',
#  'product',
#  'contains',
#  'us',
#  'persons',
#  'information',
#  'included',
#  'consistent',
#  'applicable',
#  'laws',
#  'directives',
#  'policies',
#  'handle',
#  'accordance',
#  'r',
#  'contents',
#  'introduction',
#  'contents',
#  'foreword',
#  'global',
#  'threats',
#  'cyber',
#  'online',
#  'influence',
#  'operations',
#  'election',
#  'interference',
#  'weapons',
#  'mass',
#  'destruction',
#  'proliferation',
#  'terrorism',
#  'counterintelligence',
#  'emerging',
#  'disruptive',
#  'technologies',
#  'threats',
#  'economiccompetitiveness',
#  'space',
#  'counterspace',
#  'transn',
#  'ational',
#  'organized',
#  'crime',
#  'economics',
#  'energy',
#  'human',
#  'security',
#  'regional',
#  'threats',
#  'china',
#  'russia',
#  'east',
#  'asia',
#  'middle',
#  'east',
#  'north',
#  'africa',
#  'south',
#  'asia',
#  'russia',
#  'eurasia',
#  'europe',
#  'africa',
#  'western',
#  'hemisphere',
#  'foreword',
#  'threats',
#  'us',
#  'national',
#  'security',
#  'expand',
#  'diversify',
#  'coming',
#  'year',
#  'driven',
#  'part',
#  'china',
#  'russia',
#  'respectively',
#  'compete',
#  'intensely',
#  'united',
#  'states',
#  'traditional',
#  'allies',
#  'partners',
#  'competition',
#  'cuts',
#  'across',
#  'domains',
#  'involves',
#  'race',
#  'technological',
#  'military',
#  'superiority',
#  'creasingly',
#  'values',
#  'russia',
#  'china',
#  'seek',
#  'shape',
#  'international',
#  'system',
#  'regional',
#  'security',
#  'dynamics',
#  'exert',
#  'influence',
#  'politics',
#  'economies',
#  'states',
#  'regions',
#  'world',
#  'especially',
#  'respective',
#  'backyards',
#  'china',
#  'russia',
#  'aligned',
#  'point',
#  'since',
#  'mid',
#  'relationship',
#  'likely',
#  'strengthen',
#  'coming',
#  'year',
#  'interests',
#  'threat',
#  'perceptions',
#  'converge',
#  'particularly',
#  'regarding',
#  'perceived',
#  'us',
#  'unilateralism',
#  'inter',
#  'ventionism',
#  'western',
#  'promotion',
#  'democratic',
#  'values',
#  'human',
#  'rights',
#  'china',
#  'russia',
#  'seek',
#  'expand',
#  'global',
#  'influence',
#  'eroding',
#  'well',
#  'established',
#  'security',
#  'rms',
#  'increasing',
#  'risk',
#  'regional',
#  'conflicts',
#  'particularly',
#  'middle',
#  'east',
#  'east',
#  'asia',
#  'time',
#  'us',
#  'allies',
#  'partners',
#  'seeking',
#  'greater',
#  'independence',
#  'washington',
#  'response',
#  'perceptions',
#  'changing',
#  'us',
#  'policies',
#  'security',
#  'trade',
#  'becomi',
#  'ng',
#  'open',
#  'new',
#  'bilateral',
#  'multilateral',
#  'partnerships',
#  'post',
#  'world',
#  'war',
#  'ii',
#  'international',
#  'system',
#  'comin',
#  'g',
#  'increasing',
#  'strain',
#  'amid',
#  'continuing',
#  'cyber',
#  'wmd',
#  'proliferation',
#  'threats',
#  'competition',
#  'space',
#  'regional',
#  'conflicts',
#  'among',
#  'distu',
#  'rbi',
#  'ng',
#  'trends',
#  'hostile',
#  'states',
#  'elections',
#  'abroad',
#  'use',
#  'chemical',
#  'weapons',
#  'terrorism',
#  'continue',
#  'top',
#  'threat',
#  'us',
#  'partner',
#  'interests',
#  'worldwide',
#  'particu',
#  'larly',
#  'subsaharan',
#  'africa',
#  'middle',
#  'east',
#  'south',
#  'asia',
#  'southeast',
#  'asia',
#  'development',
#  'application',
#  'new',
#  'technologies',
#  'introduce',
#  'risks',
#  'opportunities',
#  'us',
#  'economy',
#  'challenged',
#  'slower',
#  'global',
#  'economic',
#  'growth',
#  'growi',
#  'ng',
#  'threats',
#  'us',
#  'economic',
#  'competitiveness',
#  'migration',
#  'likely',
#  'continue',
#  'fuel',
#  'social',
#  'interstate',
#  'tensions',
#  'globally',
#  'drugs',
#  'transnational',
#  'organized',
#  'crime',
#  'take',
#  'toll',
#  'us',
#  'public',
#  'health',
#  'safety',
#  'political',
#  'turbulence',
#  'rising',
#  'many',
#  'gions',
#  'governance',
#  'erodes',
#  'states',
#  'confront',
#  'growing',
#  'public',
#  'alth',
#  'environmental',
#  'threats',
#  'rise',
#  'nationalism',
#  'europe',
#  'stoke',
#  'tensions',
#  'global',
#  'hre',
#  'ats',
#  'cyber',
#  'adversaries',
#  'strategic',
#  'competitors',
#  'increasingly',
#  'use',
#  'cyber',
#  'capabilities',
#  'including',
#  'cyber',
#  'espionage',
#  'attack',
#  'influence',
#  'seek',
#  'political',
#  'economic',
#  'military',
#  'advantage',
#  'united',
#  'states',
#  'allies',
#  'partners',
#  'china',
#  'russia',
#  'iran',
#  'north',
#  'korea',
#  'increasingly',
#  'use',
#  'cyber',
#  'operations',
#  'threaten',
#  'minds',
#  'machines',
#  'expanding',
#  'number',
#  'ways',
#  'steal',
#  'information',
#  'influence',
#  'citizens',
#  'disrupt',
#  'critical',
#  'infrastructure',
#  'present',
#  'china',
#  'russia',
#  'p',
#  'ose',
#  'greatest',
#  'espionage',
#  'cyber',
#  'attack',
#  'threats',
#  'anticipate',
#  'adversaries',
#  'strategic',
#  'competitors',
#  'increasingly',
#  'build',
#  'integrate',
#  'cyber',
#  'espionage',
#  'attack',
#  'influence',
#  'capabilities',
#  'efforts',
#  'influence',
#  'us',
#  'policies',
#  'advance',
#  'national',
#  'security',
#  'interests',
#  'last',
#  'decade',
#  'adversaries',
#  'strategic',
#  'competitors',
#  'developed',
#  'experimented',
#  'growing',
#  'capability',
#  'shape',
#  'alter',
#  'information',
#  'systems',
#  'rely',
#  'years',
#  'ha',
#  'conducted',
#  'cyber',
#  'espionage',
#  'collect',
#  'intelligence',
#  'targeted',
#  'critical',
#  'infrastructure',
#  'hold',
#  'risk',
#  'becoming',
#  'adept',
#  'using',
#  'social',
#  'media',
#  'alter',
#  'think',
#  'behave',
#  'decide',
#  'connect',
#  'integrate',
#  'billions',
#  'new',
#  'digital',
#  'devices',
#  'lives',
#  'business',
#  'processes',
#  'adversaries',
#  'strategic',
#  'competitors',
#  'almost',
#  'certainly',
#  'gain',
#  'greater',
#  'insight',
#  'access',
#  'protected',
#  'information',
#  'china',
#  'china',
#  'presents',
#  'persistent',
#  'cyber',
#  'espionage',
#  'threat',
#  'growing',
#  'attack',
#  'threat',
#  'core',
#  'military',
#  'critical',
#  'infrastructure',
#  'systems',
#  'china',
#  'remains',
#  'active',
#  'strategic',
#  'competitor',
#  'responsible',
#  'cyber',
#  'espionage',
#  'us',
#  'government',
#  'corporations',
#  'allies',
#  'improving',
#  'cyber',
#  'attack',
#  'capabilities',
#  'altering',
#  'information',
#  'online',
#  'shaping',
#  'chinese',
#  'views',
#  'potentially',
#  'views',
#  'us',
#  'citizens',
#  'issue',
#  'discuss',
#  'greater',
#  'detail',
#  'online',
#  'influence',
#  'operations',
#  'election',
#  'interference',
#  'section',
#  'report',
#  'beijing',
#  'authorize',
#  'cyber',
#  'espiona',
#  'ge',
#  'key',
#  'us',
#  'technology',
#  'sectors',
#  'addresses',
#  'significant',
#  'national',
#  'security',
#  'economic',
#  'goal',
#  'achievable',
#  'means',
#  'also',
#  'concern',
#  'ed',
#  'potential',
#  'chinese',
#  'intelligence',
#  'security',
#  'services',
#  'use',
#  'chinese',
#  'information',
#  'technology',
#  'firms',
#  'routine',
#  'systemic',
#  'espionage',
#  'platform',
#  'united',
#  'states',
#  'allies',
#  'china',
#  'ability',
#  'launch',
#  'cyber',
#  'attacks',
#  'cause',
#  'localized',
#  'temporary',
#  'disruptive',
#  'effects',
#  'critical',
#  'infrastructure',
#  'disruption',
#  'natural',
#  'gas',
#  'pipeline',
#  'days',
#  'weeks',
#  'united',
#  'states',
#  'russia',
#  'assess',
#  'r',
#  'ussia',
#  'poses',
#  'cyber',
#  'espionage',
#  'influence',
#  'attack',
#  'threat',
#  'united',
#  'states',
#  'allies',
#  'moscow',
#  'continues',
#  'highly',
#  'capable',
#  'effective',
#  'adversary',
#  'integr',
#  'ating',
#  'cyber',
#  'espionage',
#  'attack',
#  'influence',
#  'operations',
#  'achieve',
#  'political',
#  'military',
#  'objectives',
#  'moscow',
#  'staging',
#  'cyber',
#  'attack',
#  'assets',
#  'allow',
#  'disrupt',
#  'damage',
#  'us',
#  'civilian',
#  'military',
#  'infrastructure',
#  'crisis',
#  'poses',
#  'signif',
#  'icant',
#  'cyber',
#  'influence',
#  'threat',
#  'issue',
#  'discussed',
#  'online',
#  'influence',
#  'operations',
#  'election',
#  'interference',
#  'section',
#  'report',
#  'russian',
#  'intelligence',
#  'security',
#  'services',
#  'continue',
#  'targeting',
#  'us',
#  'information',
#  'systems',
#  'well',
#  'networks',
#  'nato',
#  'five',
#  'eyes',
#  'partners',
#  'technical',
#  'information',
#  'military',
#  'russia',
#  'ability',
#  'execute',
#  'cyber',
#  'attacks',
#  'united',
#  'states',
#  'generate',
#  'localized',
#  'temporary',
#  'disruptive',
#  'effects',
#  'critical',
#  'infra',
#  'structure',
#  'disrupting',
#  'electrical',
#  'distribution',
#  'network',
#  'least',
#  'hours',
#  'similar',
#  'demonstrated',
#  'ukraine',
#  'moscow',
#  'mapping',
#  'critical',
#  'infrastructure',
#  'long',
#  'term',
#  'goal',
#  'able',
#  'cause',
#  'substantial',
#  'da',
#  'mage',
#  'iran',
#  'iran',
#  'continues',
#  'present',
#  'cyber',
#  'espionage',
#  'attack',
#  'threat',
#  'iran',
#  'us',
#  'es',
#  'increasingly',
#  'sophisticated',
#  'cyber',
#  'techniques',
#  'conduct',
#  'espionage',
#  'also',
#  'attempting',
#  'deploy',
#  'cyber',
#  'attack',
#  'capabilities',
#  'would',
#  'enable',
#  'attacks',
#  'critical',
#  'infrastructure',
#  'united',
#  'states',
#  'allied',
#  'countries',
#  'tehran',
#  'also',
#  'uses',
#  'social',
#  'media',
#  'platforms',
#  'target',
#  'us',
#  'allied',
#  'audiences',
#  'issue',
#  'discussed',
#  'online',
#  'influence',
#  'operations',
#  'election',
#  'interference',
#  'section',
#  'r',
#  'eport',
#  'iranian',
#  'cyber',
#  'actors',
#  'targeting',
#  'us',
#  'government',
#  'officials',
#  'government',
#  'organizations',
#  'companies',
#  'gain',
#  'intelligence',
#  'position',
#  'future',
#  'cyber',
#  'operations',
#  'iran',
#  'preparing',
#  'cyber',
#  'attacks',
#  'united',
#  'states',
#  'allies',
#  'capable',
#  'causing',
#  'localized',
#  'temporary',
#  'disruptive',
#  'eff',
#  'ects',
#  'disrupting',
#  'large',
#  'corporate',
#  'networks',
#  'days',
#  'weeks',
#  'similar',
#  'data',
#  'deletion',
#  'att',
#  'acks',
#  'dozens',
#  'saudi',
#  'governmental',
#  'private',
#  'sector',
#  'networks',
#  'late',
#  'early',
#  'north',
#  'korea',
#  'north',
#  'korea',
#  'poses',
#  'significant',
#  'cyber',
#  'threat',
#  'financial',
#  'institutions',
#  'remains',
#  'cyber',
#  'espionage',
#  'threat',
#  'retains',
#  'ability',
#  'conduct',
#  'disr',
#  'uptive',
#  'cyber',
#  'attacks',
#  'north',
#  'korea',
#  'continues',
#  'use',
#  'cyber',
#  'capabilities',
#  'steal',
#  'financial',
#  'institutions',
#  'attempts',
#  'steal',
#  'billion',
#  'financial',
#  'institutions',
#  'across',
#  'worl',
#  'dincluding',
#  'successful',
#  'cyber',
#  'heist',
#  'estimated',
#  'million',
#  'new',
#  'york',
#  'federal',
#  'reserve',
#  'account',
#  'nonstate',
#  'unattributed',
#  'actors',
#  'foreign',
#  'cyber',
#  'criminals',
#  'continue',
#  'conduct',
#  'profit',
#  'cyber',
#  'enabled',
#  'theft',
#  'e',
#  'xtortion',
#  'us',
#  'networks',
#  'anticipate',
#  'f',
#  'inancially',
#  'motivated',
#  'cyber',
#  'criminals',
#  'likely',
#  'expand',
#  'targets',
#  'united',
#  'states',
#  'next',
#  'years',
#  'actions',
#  'could',
#  'increasingly',
#  'disrupt',
#  'us',
#  'critical',
#  'infrastructure',
#  'health',
#  'car',
#  'e',
#  'financial',
#  'government',
#  'emergency',
#  'service',
#  'sectors',
#  'based',
#  'patterns',
#  'activities',
#  'sectors',
#  'last',
#  'years',
#  'terrorists',
#  'could',
#  'obtain',
#  'disclose',
#  'compromising',
#  'personally',
#  'identifiable',
#  'information',
#  'cyber',
#  'operations',
#  'may',
#  'use',
#  'disclosures',
#  'coerce',
#  'extort',
#  'inspire',
#  'enable',
#  'physical',
#  'attacks',
#  'victims',
#  'terrorist',
#  'groups',
#  'could',
#  'cause',
#  'disruptive',
#  'effects',
#  'defacing',
#  'websites',
#  'executing',
#  'denial',
#  'ofservice',
#  'attacks',
#  'poorly',
#  'protected',
#  'netwo',
#  'rks',
#  'little',
#  'warning',
#  'growing',
#  'availability',
#  'use',
#  'publicly',
#  'commercially',
#  'available',
#  'cyber',
#  'tools',
#  'increasing',
#  'overall',
#  'volume',
#  'unattributed',
#  'cyber',
#  'activity',
#  'around',
#  'world',
#  'use',
#  'tools',
#  'increases',
#  'risk',
#  'misattributions',
#  'mis',
#  'direct',
#  'ed',
#  'responses',
#  'governments',
#  'private',
#  'sector',
#  'online',
#  'influence',
#  'ope',
#  'rations',
#  'election',
#  'interference',
#  'adversaries',
#  'strategic',
#  'competitors',
#  'probably',
#  'already',
#  'looking',
#  'us',
#  ...]

# %%
#Cria a função para retirar as stopwords
stop_lambda = lambda x: [y for y in x if y not in stop_words_en]
#aplica a função na coluna dos tokens
a['tokens_stop'] = a.token.apply(stop_lambda)
a.head()
# Out:
#                                               pagina  \
# 0       january    senate select committee on int...
# 1    statement for the record     worldwide threa...
# 2    contents  introduction                      ...
# 3     foreword  threats to us national security w...
# 4     global t hre ats  cyber  our adversaries  a...
#
#                                                token  \
# 0  [january, senate, select, committee, on, intel...
# 1  [statement, for, the, record, worldwide, threa...
# 2  [contents, introduction, contents, foreword, g...
# 3  [foreword, threats, to, us, national, security...
# 4  [global, t, hre, ats, cyber, our, adversaries,...
#
#                                          tokens_stop
# 0  [january, senate, select, committee, intellige...
# 1  [statement, record, worldwide, threat, assessm...
# 2  [contents, introduction, contents, foreword, g...
# 3  [foreword, threats, us, national, security, ex...
# 4  [global, hre, ats, cyber, adversaries, strateg...

# %%
word_list_clean = sum(a.tokens_stop.tolist(), [])

word_list_clean[:10]
# Out:
# ['january',
#  'senate',
#  'select',
#  'committee',
#  'intelligence',
#  'statement',
#  'record',
#  'worldwide',
#  'threat',
#  'assessment']

# %%
# Converte a lista em um dicionário com contagem de valores
word_counts_clean = Counter(word_list_clean)
b = word_counts_clean

# Inverta a chave / valores no dicionário para classificar
word_counts_clean = list(zip(word_counts_clean.values(), word_counts_clean.keys()))

# Classifique a lista por contagem
word_counts_clean = sorted(word_counts_clean, reverse=True)

# Imprime as 10 palavras mais comuns
word_counts_clean[:10]
# Out:
# [(116, 'us'),
#  (59, 'states'),
#  (57, 'china'),
#  (55, 'military'),
#  (52, 'economic'),
#  (49, 'united'),
#  (48, 'continue'),
#  (47, 'russia'),
#  (45, 'influence'),
#  (43, 'security')]

# %%
from wordcloud import WordCloud

text = word_list_clean
wordcloud = WordCloud(width=1600, height=800, max_font_size=200).fit_words(b) # o 'a' veio de um counter
#wordcloud = WordCloud(width=1600, height=800, max_font_size=200).generate(text)
plt.figure(figsize=(16,13))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('wordcloud.png', dpi=600)
plt.show()

# %%
plt.savefig(wordcloud, 'wordcloud.png',dpi=600)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-f51090528a33> in <module>
# ----> 1 plt.savefig(wordcloud, 'wordcloud.png',dpi=600)
#
# D:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# TypeError: savefig() takes 2 positional arguments but 3 were given

# %%
b
# Out:
# Counter({'january': 4,
#          'senate': 1,
#          'select': 1,
#          'committee': 4,
#          'intelligence': 22,
#          'statement': 3,
#          'record': 4,
#          'worldwide': 4,
#          'threat': 33,
#          'assessment': 3,
#          'us': 116,
#          'community': 7,
#          'introduction': 2,
#          'chairman': 2,
#          'burr': 1,
#          'vice': 1,
#          'warner': 1,
#          'members': 3,
#          'thank': 1,
#          'invitation': 1,
#          'threats': 19,
#          'national': 18,
#          'security': 43,
#          'en': 1,
#          'men': 2,
#          'privileged': 1,
#          'honored': 1,
#          'lead': 7,
#          'committed': 2,
#          'every': 1,
#          'day': 1,
#          'providing': 3,
#          'nuanced': 1,
#          'independent': 2,
#          'unvarnished': 1,
#          'policymakers': 1,
#          'warfighters': 1,
#          'domestic': 9,
#          'law': 6,
#          'enforcement': 4,
#          'personnel': 3,
#          'need': 4,
#          'protect': 2,
#          'american': 4,
#          'lives': 2,
#          'order': 6,
#          'topics': 1,
#          'presented': 1,
#          'necessarily': 1,
#          'indicate': 2,
#          'relative': 2,
#          'importance': 1,
#          'magnitude': 1,
#          'view': 7,
#          'informa': 1,
#          'tion': 1,
#          'available': 2,
#          'jan': 1,
#          'uary': 1,
#          'used': 5,
#          'preparation': 1,
#          'attention': 2,
#          'product': 1,
#          'contains': 1,
#          'persons': 2,
#          'information': 20,
#          'included': 3,
#          'consistent': 1,
#          'applicable': 1,
#          'laws': 1,
#          'directives': 1,
#          'policies': 6,
#          'handle': 1,
#          'accordance': 1,
#          'r': 8,
#          'contents': 2,
#          'foreword': 2,
#          'global': 30,
#          'cyber': 43,
#          'online': 8,
#          'influence': 45,
#          'operations': 22,
#          'election': 12,
#          'interference': 5,
#          'weapons': 29,
#          'mass': 5,
#          'destruction': 3,
#          'proliferation': 3,
#          'terrorism': 4,
#          'counterintelligence': 3,
#          'emerging': 8,
#          'disruptive': 5,
#          'technologies': 9,
#          'economiccompetitiveness': 1,
#          'space': 24,
#          'counterspace': 3,
#          'transn': 1,
#          'ational': 1,
#          'organized': 4,
#          'crime': 7,
#          'economics': 3,
#          'energy': 9,
#          'human': 23,
#          'regional': 17,
#          'china': 57,
#          'russia': 47,
#          'east': 13,
#          'asia': 21,
#          'middle': 9,
#          'north': 26,
#          'africa': 16,
#          'south': 18,
#          'eurasia': 2,
#          'europe': 8,
#          'western': 11,
#          'hemisphere': 3,
#          'expand': 15,
#          'diversify': 4,
#          'coming': 8,
#          'year': 24,
#          'driven': 1,
#          'part': 6,
#          'respectively': 3,
#          'compete': 1,
#          'intensely': 1,
#          'united': 49,
#          'states': 59,
#          'traditional': 4,
#          'allies': 18,
#          'partners': 13,
#          'competition': 6,
#          'cuts': 1,
#          'across': 8,
#          'domains': 3,
#          'involves': 1,
#          'race': 2,
#          'technological': 3,
#          'military': 55,
#          'superiority': 1,
#          'creasingly': 1,
#          'values': 2,
#          'seek': 17,
#          'shape': 7,
#          'international': 21,
#          'system': 8,
#          'dynamics': 2,
#          'exert': 2,
#          'politics': 4,
#          'economies': 5,
#          'regions': 4,
#          'world': 8,
#          'especially': 7,
#          'respective': 1,
#          'backyards': 1,
#          'aligned': 2,
#          'point': 1,
#          'since': 9,
#          'mid': 3,
#          'relationship': 3,
#          'likely': 31,
#          'strengthen': 3,
#          'interests': 25,
#          'perceptions': 3,
#          'converge': 1,
#          'particularly': 9,
#          'regarding': 1,
#          'perceived': 4,
#          'unilateralism': 1,
#          'inter': 2,
#          'ventionism': 1,
#          'promotion': 1,
#          'democratic': 5,
#          'rights': 8,
#          'eroding': 2,
#          'well': 12,
#          'established': 1,
#          'rms': 1,
#          'increasing': 16,
#          'risk': 21,
#          'conflicts': 5,
#          'time': 2,
#          'seeking': 4,
#          'greater': 4,
#          'independence': 1,
#          'washington': 3,
#          'response': 5,
#          'changing': 1,
#          'trade': 14,
#          'becomi': 1,
#          'ng': 5,
#          'open': 3,
#          'new': 22,
#          'bilateral': 3,
#          'multilateral': 2,
#          'partnerships': 5,
#          'post': 2,
#          'war': 3,
#          'ii': 1,
#          'comin': 1,
#          'g': 5,
#          'strain': 2,
#          'amid': 1,
#          'continuing': 5,
#          'wmd': 9,
#          'among': 6,
#          'distu': 1,
#          'rbi': 1,
#          'trends': 1,
#          'hostile': 2,
#          'elections': 14,
#          'abroad': 5,
#          'use': 30,
#          'chemical': 6,
#          'continue': 48,
#          'top': 2,
#          'partner': 2,
#          'particu': 1,
#          'larly': 1,
#          'subsaharan': 1,
#          'southeast': 10,
#          'development': 9,
#          'application': 2,
#          'introduce': 3,
#          'risks': 10,
#          'opportunities': 4,
#          'economy': 5,
#          'challenged': 2,
#          'slower': 2,
#          'economic': 52,
#          'growth': 16,
#          'growi': 1,
#          'competitiveness': 3,
#          'migration': 6,
#          'fuel': 4,
#          'social': 11,
#          'interstate': 2,
#          'tensions': 18,
#          'globally': 1,
#          'drugs': 5,
#          'transnational': 6,
#          'take': 4,
#          'toll': 1,
#          'public': 13,
#          'health': 9,
#          'safety': 3,
#          'political': 33,
#          'turbulence': 1,
#          'rising': 3,
#          'many': 11,
#          'gions': 1,
#          'governance': 8,
#          'erodes': 1,
#          'confront': 3,
#          'growing': 9,
#          'alth': 1,
#          'environmental': 3,
#          'rise': 6,
#          'nationalism': 1,
#          'stoke': 2,
#          'hre': 1,
#          'ats': 1,
#          'adversaries': 17,
#          'strategic': 16,
#          'competitors': 11,
#          'increasingly': 10,
#          'capabilities': 35,
#          'including': 35,
#          'espionage': 12,
#          'attack': 18,
#          'advantage': 5,
#          'iran': 37,
#          'korea': 17,
#          'threaten': 11,
#          'minds': 1,
#          'machines': 1,
#          'expanding': 3,
#          'number': 6,
#          'ways': 4,
#          'steal': 3,
#          'citizens': 4,
#          'disrupt': 7,
#          'critical': 12,
#          'infrastructure': 22,
#          'present': 9,
#          'p': 2,
#          'ose': 1,
#          'greatest': 2,
#          'anticipate': 4,
#          'build': 4,
#          'integrate': 2,
#          'efforts': 22,
#          'advance': 4,
#          'last': 4,
#          'decade': 3,
#          'developed': 3,
#          'experimented': 1,
#          'capability': 5,
#          'alter': 4,
#          'systems': 15,
#          'rely': 4,
#          'years': 16,
#          'ha': 2,
#          'conducted': 7,
#          'collect': 3,
#          'targeted': 3,
#          'hold': 5,
#          'becoming': 3,
#          'adept': 1,
#          'using': 10,
#          'media': 9,
#          'think': 2,
#          'behave': 1,
#          'decide': 1,
#          'connect': 1,
#          'billions': 1,
#          'digital': 1,
#          'devices': 1,
#          'business': 3,
#          'processes': 1,
#          'almost': 14,
#          'certainly': 13,
#          'gain': 8,
#          'insight': 1,
#          'access': 12,
#          'protected': 2,
#          'presents': 1,
#          'persistent': 4,
#          'core': 2,
#          'remains': 9,
#          'active': 3,
#          'competitor': 1,
#          'responsible': 2,
#          'government': 22,
#          'corporations': 1,
#          'improving': 2,
#          'altering': 1,
#          'shaping': 1,
#          'chinese': 22,
#          'views': 6,
#          'potentially': 1,
#          'issue': 5,
#          'discuss': 1,
#          'detail': 1,
#          'section': 4,
#          'report': 3,
#          'beijing': 10,
#          'authorize': 1,
#          'espiona': 1,
#          'ge': 1,
#          'key': 16,
#          'technology': 8,
#          'sectors': 3,
#          'addresses': 1,
#          'significant': 7,
#          'goal': 3,
#          'achievable': 1,
#          'means': 5,
#          'also': 25,
#          'concern': 2,
#          'ed': 5,
#          'potential': 7,
#          'services': 17,
#          'firms': 2,
#          'routine': 1,
#          'systemic': 1,
#          'platform': 2,
#          'ability': 10,
#          'launch': 3,
#          'attacks': 27,
#          'cause': 4,
#          'localized': 3,
#          'temporary': 3,
#          'effects': 8,
#          'disruption': 2,
#          'natural': 5,
#          'gas': 2,
#          'pipeline': 1,
#          'days': 2,
#          'weeks': 2,
#          'assess': 30,
#          'ussia': 2,
#          'poses': 6,
#          'moscow': 10,
#          'continues': 13,
#          'highly': 2,
#          'capable': 14,
#          'effective': 2,
#          'adversary': 5,
#          'integr': 1,
#          'ating': 1,
#          'achieve': 2,
#          'objectives': 4,
#          'staging': 1,
#          'assets': 2,
#          'allow': 3,
#          'damage': 6,
#          'civilian': 1,
#          'crisis': 7,
#          'signif': 1,
#          'icant': 1,
#          'discussed': 2,
#          'russian': 12,
#          'targeting': 4,
#          'networks': 9,
#          'nato': 3,
#          'five': 1,
#          'eyes': 1,
#          'technical': 4,
#          'execute': 2,
#          'generate': 1,
#          'infra': 1,
#          'structure': 3,
#          'disrupting': 3,
#          'electrical': 1,
#          'distribution': 2,
#          'network': 3,
#          'least': 4,
#          'hours': 1,
#          'similar': 6,
#          'demonstrated': 1,
#          'ukraine': 3,
#          'mapping': 1,
#          'long': 8,
#          'term': 9,
#          'able': 3,
#          'substantial': 1,
#          'da': 1,
#          'mage': 1,
#          'es': 1,
#          'sophisticated': 2,
#          'techniques': 1,
#          'conduct': 5,
#          'attempting': 1,
#          'deploy': 2,
#          'would': 10,
#          'enable': 4,
#          'allied': 8,
#          'countries': 30,
#          'tehran': 2,
#          'uses': 1,
#          'platforms': 2,
#          'target': 8,
#          'audiences': 2,
#          'eport': 1,
#          'iranian': 16,
#          'actors': 14,
#          'officials': 3,
#          'organizations': 5,
#          'companies': 5,
#          'position': 4,
#          'future': 5,
#          'preparing': 1,
#          'causing': 1,
#          'eff': 1,
#          'ects': 1,
#          'large': 11,
#          'corporate': 1,
#          'data': 8,
#          'deletion': 1,
#          'att': 1,
#          'acks': 1,
#          'dozens': 3,
#          'saudi': 11,
#          'governmental': 1,
#          'private': 5,
#          'sector': 7,
#          'late': 6,
#          'early': 3,
#          'financial': 7,
#          'institutions': 6,
#          'retains': 3,
#          'disr': 1,
#          'uptive': 1,
#          'attempts': 1,
#          'billion': 4,
#          'worl': 1,
#          'dincluding': 1,
#          'successful': 2,
#          'heist': 1,
#          'estimated': 3,
#          'million': 6,
#          'york': 1,
#          'federal': 1,
#          'reserve': 1,
#          'account': 1,
#          'nonstate': 6,
#          'unattributed': 2,
#          'foreign': 24,
#          'criminals': 5,
#          'profit': 1,
#          'enabled': 2,
#          'theft': 4,
#          'e': 10,
#          'xtortion': 1,
#          'f': 4,
#          'inancially': 1,
#          'motivated': 2,
#          'targets': 5,
#          'next': 8,
#          'actions': 3,
#          'could': 20,
#          'car': 2,
#          'emergency': 1,
#          'service': 3,
#          'based': 17,
#          'patterns': 1,
#          'activities': 9,
#          'terrorists': 2,
#          'obtain': 3,
#          'disclose': 1,
#          'compromising': 1,
#          'personally': 1,
#          'identifiable': 1,
#          'may': 15,
#          'disclosures': 1,
#          'coerce': 1,
#          'extort': 1,
#          'inspire': 2,
#          'physical': 2,
#          'victims': 1,
#          'terrorist': 11,
#          'groups': 27,
#          'defacing': 1,
#          'websites': 1,
#          'executing': 1,
#          'denial': 2,
#          'ofservice': 1,
#          'poorly': 1,
#          'netwo': 1,
#          'rks': 1,
#          'little': 2,
#          'warning': 1,
#          'availability': 2,
#          'publicly': 4,
#          'commercially': 1,
#          'tools': 6,
#          'overall': 5,
#          'volume': 1,
#          'activity': 6,
#          'around': 4,
#          'increases': 1,
#          'misattributions': 1,
#          'mis': 1,
#          'direct': 4,
#          'responses': 1,
#          'governments': 10,
#          'ope': 1,
#          'rations': 1,
#          'probably': 24,
#          'already': 4,
#          'looking': 1,
#          'opportunity': 2,
#          'broadly': 1,
#          'try': 5,
#          'weaken': 2,
#          'undermine': 5,
#          'alliances': 1,
#          'policy': 9,
#          'outcomes': 2,
#          'unit': 1,
#          'elsewhere': 2,
#          'expect': 12,
#          'refine': 1,
#          'add': 1,
#          'tactics': 2,
#          'learn': 1,
#          'suggesting': 2,
#          'landscape': 1,
#          'look': 1,
#          'different': 2,
#          'electio': 1,
#          'ns': 1,
#          'racial': 1,
#          'undermining': 4,
#          'trust': 1,
#          'authorities': 3,
#          'criticizing': 1,
#          'anti': 5,
#          'politicians': 2,
#          'employ': 2,
#          'additional': 5,
#          'toolkits': 1,
#          'spreading': 1,
#          'disinformation': 1,
#          'conducting': 2,
#          'hack': 1,
#          'leak': 1,
#          'manipulating': 1,
#          'fashion': 1,
#          'controls': 2,
#          'environment': 6,
#          'inside': 2,
#          'ts': 2,
#          'discourse': 2,
#          'relating': 1,
#          'issues': 3,
#          'party': 5,
#          'legitimacy': 2,
#          'taiwan': 5,
#          'tibet': 1,
#          'legal': 3,
#          'levers': 2,
#          'lure': 1,
#          'markets': 6,
#          'censor': 1,
#          'suppress': 1,
#          'viewpoints': 1,
#          'deems': 1,
#          'politically': 5,
#          'sensitive': 5,
#          'campaigns': 3,
#          'nations': 4,
#          'messages': 1,
#          'attempt': 5,
#          'deep': 3,
#          'fakes': 1,
#          'machine': 1,
#          'learning': 1,
#          'create': 2,
#          'convincing': 1,
#          'false': 1,
#          'image': 2,
#          'audio': 1,
#          'video': 1,
#          'files': 1,
#          'augment': 1,
#          'directed': 1,
#          'directly': 2,
#          'manipulate': 1,
#          'tampering': 1,
#          'voter': 1,
#          'registration': 1,
#          'vote': 3,
#          'tallying': 1,
#          'process': 4,
#          'either': 3,
#          'call': 3,
#          'question': 1,
#          'voting': 2,
#          'unidentified': 1,
#          'recently': 2,
#          'reporting': 2,
#          'compromise': 2,
#          'ented': 1,
#          'changed': 1,
#          'counts': 1,
#          'tally': 1,
#          'votes': 1,
#          'grow': 2,
#          'note': 1,
#          'particular': 1,
#          'posed': 2,
#          'warfare': 5,
#          'cw': 4,
#          'following': 3,
#          'sustained': 3,
#          'decades': 1,
#          'trend': 2,
#          'erode': 3,
#          'norms': 2,
#          'programs': 7,
#          'shift': 1,
#          'cost': 3,
#          'benefit': 1,
#          'analys': 1,
#          'might': 7,
#          'consider': 1,
#          'developing': 7,
#          'syria': 18,
#          'isis': 18,
#          'battlefield': 3,
#          'assassination': 2,
#          'past': 12,
#          'two': 4,
#          'cluded': 1,
#          'agents': 4,
#          'toxic': 1,
#          'industrial': 1,
#          'chemicals': 1,
#          'first': 4,
#          'known': 2,
#          'novichok': 1,
#          'nerve': 1,
#          'agent': 3,
#          'biological': 2,
#          'become': 4,
#          'diverse': 1,
#          'bw': 1,
#          'employed': 1,
#          'variety': 4,
#          'made': 3,
#          'eas': 2,
#          'ier': 1,
#          'dual': 1,
#          'pyongyang': 2,
#          'nuclear': 28,
#          'missile': 13,
#          'tests': 2,
#          'declared': 2,
#          'support': 15,
#          'denuclearization': 8,
#          'korean': 10,
#          'peninsula': 2,
#          'reversibly': 1,
#          'dismantled': 2,
#          'portions': 2,
#          'however': 10,
#          'ic': 4,
#          'unlikely': 6,
#          'give': 2,
#          'stockpiles': 1,
#          'delivery': 2,
#          'production': 8,
#          'leaders': 11,
#          'arms': 5,
#          'regime': 18,
#          'survival': 2,
#          'explanation': 1,
#          'see': 6,
#          'promised': 4,
#          'make': 8,
#          'test': 2,
#          'proliferate': 2,
#          'idea': 1,
#          'changes': 5,
#          'diplomatic': 11,
#          'ties': 8,
#          'sanctions': 18,
#          'activi': 1,
#          'observe': 2,
#          'inconsistent': 1,
#          'full': 4,
#          'addition': 2,
#          'underscored': 2,
#          'commitment': 3,
#          'n': 12,
#          'produce': 4,
#          'earlier': 2,
#          'lawand': 1,
#          'constitutional': 3,
#          'change': 7,
#          'remain': 25,
#          'beyond': 6,
#          'nonstrategic': 1,
#          'president': 13,
#          'vladimir': 3,
#          'putin': 6,
#          'annual': 1,
#          'address': 7,
#          'march': 3,
#          'acknowledge': 1,
#          'several': 7,
#          'icbm': 2,
#          'designed': 1,
#          'penetrate': 1,
#          'defense': 4,
#          'sys': 1,
#          'tems': 1,
#          'intercontinental': 1,
#          'range': 14,
#          'hypersonic': 2,
#          'glide': 1,
#          'vehicle': 4,
#          'maneuverable': 1,
#          'air': 7,
#          'launched': 4,
#          'strike': 7,
#          'powered': 2,
#          'cruise': 5,
#          'nuclea': 1,
#          'rpowered': 1,
#          'transoceanic': 1,
#          'underwater': 1,
#          'fielded': 2,
#          'ground': 3,
#          'glcm': 2,
#          'determined': 2,
#          'violates': 1,
#          'intermediate': 1,
#          'forces': 12,
#          'inf': 1,
#          'treaty': 1,
#          'believes': 2,
#          'provides': 1,
#          'sufficient': 1,
#          'advantages': 2,
#          'worth': 1,
#          'repercussions': 1,
#          'violation': 1,
#          'multiyear': 1,
#          'effort': 2,
#          'modernize': 2,
#          'deploying': 2,
#          'sea': 12,
#          'improvi': 1,
#          'road': 3,
#          'mobile': 1,
#          'silo': 1,
#          'testing': 2,
#          'deterrent': 1,
#          'second': 2,
#          'way': 4,
#          'overcome': 1,
#          'defenses': 2,
#          'publicized': 1,
#          'intent': 5,
#          'form': 1,
#          'triad': 1,
#          'generation': 3,
#          'bomber': 1,
#          'currently': 1,
#          'undertaking': 1,
#          'judge': 4,
#          'necessar': 1,
#          'device': 2,
#          'joint': 1,
#          'comprehensive': 2,
#          'plan': 5,
#          'action': 1,
#          'jcpoa': 5,
#          'commitments': 1,
#          'resume': 4,
#          'limits': 3,
#          'tangible': 1,
#          'trad': 2,
#          'investment': 4,
#          'benefits': 5,
#          'expected': 2,
#          'deal': 3,
#          'june': 2,
#          'started': 1,
#          'preparations': 1,
#          'allowable': 1,
#          'manufacture': 1,
#          'advanced': 10,
#          'centrifuges': 1,
#          'atomic': 1,
#          'organization': 4,
#          'aeoi': 1,
#          'announced': 1,
#          'producing': 2,
#          'uranium': 1,
#          'hexafluoride': 1,
#          'uf': 1,
#          'prepare': 1,
#          'necessary': 2,
#          'enrichment': 1,
#          'capacity': 3,
#          'within': 7,
#          'work': 3,
#          'participants': 1,
#          'eu': 7,
#          'ropean': 1,
#          'union': 4,
#          'france': 1,
#          'germany': 2,
#          'kingdom': 2,
#          'find': 1,
#          'sa': 2,
#          'lvage': 1,
#          'enough': 2,
#          'fissile': 1,
#          'material': 2,
#          'weapon': 2,
#          'months': 3,
#          'one': 11,
#          'pose': 4,
#          'pace': 3,
#          'slv': 1,
#          'simorgh': 1,
#          'shortens': 1,
#          'timeline': 1,
#          'slvs': 1,
#          'icbms': 1,
#          'noncompliance': 1,
#          'obligations': 1,
#          'convention': 1,
#          'cwc': 2,
#          'remai': 1,
#          'concerned': 2,
#          'intended': 5,
#          'incapacitate': 1,
#          'offensive': 5,
#          'purposes': 2,
#          'declare': 1,
#          'ratified': 1,
#          'clear': 2,
#          'increase': 18,
#          'incident': 1,
#          'types': 2,
#          'escalation': 2,
#          'region': 21,
#          'pakistan': 7,
#          'develop': 8,
#          'short': 1,
#          'tactical': 1,
#          'missiles': 11,
#          'longer': 1,
#          'ballistic': 8,
#          'india': 13,
#          'deployment': 2,
#          'submarine': 2,
#          'armed': 8,
#          'terroris': 1,
#          'sunni': 4,
#          'violent': 11,
#          'extremists': 3,
#          'jihadists': 1,
#          'local': 8,
#          'despite': 12,
#          'experienced': 1,
#          'setbacks': 2,
#          'recent': 3,
#          'striking': 1,
#          'homeland': 2,
#          'prominent': 2,
#          'jihadist': 3,
#          'ideologues': 1,
#          'justify': 1,
#          'parts': 1,
#          'expanded': 3,
#          'abilit': 1,
#          'ies': 1,
#          'insurgencies': 2,
#          'foster': 2,
#          'like': 2,
#          'minded': 1,
#          'neighboring': 3,
#          'iraq': 13,
#          'generated': 1,
#          'pool': 1,
#          'battle': 2,
#          'hardened': 1,
#          'fighters': 3,
#          'isi': 1,
#          'still': 5,
#          'commands': 2,
#          'thousands': 3,
#          'maintains': 2,
#          'eight': 1,
#          'branches': 1,
#          'dozen': 1,
#          'dispersed': 1,
#          'supporters': 2,
#          'leadership': 6,
#          'territorial': 2,
#          'losses': 4,
#          'group': 3,
#          'exploit': 7,
#          'reduction': 1,
#          'ct': 3,
#          'pressure': 11,
#          'clandestine': 1,
#          'presence': 6,
#          'accelerate': 2,
#          'rebuilding': 2,
#          'external': 3,
#          'pursue': 8,
#          'perpetrating': 1,
#          'stabilization': 1,
#          'retaliate': 2,
#          'enemies': 1,
#          'exploiting': 1,
#          'sectarian': 1,
#          'realizes': 1,
#          'control': 16,
#          'ling': 1,
#          'territory': 6,
#          'sustainable': 1,
#          'near': 6,
#          'grievances': 3,
#          'societal': 5,
#          'instability': 2,
#          'stretched': 2,
#          'regain': 2,
#          'al': 14,
#          'ing': 6,
#          'encourage': 1,
#          'west': 4,
#          'although': 7,
#          'date': 1,
#          'small': 3,
#          'scale': 6,
#          'limited': 3,
#          'area': 2,
#          'challenge': 8,
#          'havens': 2,
#          'resources': 9,
#          'dle': 1,
#          'maintained': 2,
#          'high': 17,
#          'ye': 1,
#          'exp': 2,
#          'anded': 1,
#          'areas': 7,
#          'conflict': 12,
#          'homegrown': 2,
#          'hves': 2,
#          'acute': 3,
#          'hve': 3,
#          ...})

# %%
from nltk import ngrams
a['bi_gram'] = ngrams(a.tokens_stop,2)

# %%
a.head()
# Out:
#                                               pagina  \
# 0       january    senate select committee on int...
# 1    statement for the record     worldwide threa...
# 2    contents  introduction                      ...
# 3     foreword  threats to us national security w...
# 4     global t hre ats  cyber  our adversaries  a...
#
#                                                token  \
# 0  [january, senate, select, committee, on, intel...
# 1  [statement, for, the, record, worldwide, threa...
# 2  [contents, introduction, contents, foreword, g...
# 3  [foreword, threats, to, us, national, security...
# 4  [global, t, hre, ats, cyber, our, adversaries,...
#
#                                          tokens_stop  \
# 0  [january, senate, select, committee, intellige...
# 1  [statement, record, worldwide, threat, assessm...
# 2  [contents, introduction, contents, foreword, g...
# 3  [foreword, threats, us, national, security, ex...
# 4  [global, hre, ats, cyber, adversaries, strateg...
#
#                                            bi_gram
# 0  <generator object ngrams at 0x0000022AB7FB6148>
# 1  <generator object ngrams at 0x0000022AB7FB6148>
# 2  <generator object ngrams at 0x0000022AB7FB6148>
# 3  <generator object ngrams at 0x0000022AB7FB6148>
# 4  <generator object ngrams at 0x0000022AB7FB6148>

# %%
list(ngrams(a.tokens_stop[0],2))
# Out:
# [('january', 'senate'),
#  ('senate', 'select'),
#  ('select', 'committee'),
#  ('committee', 'intelligence')]

# %%
word_counts_clean[0]
# Out:
# (116, 'us')

# %%
f=open('f1.txt','w')
#s1='\n'.join(word_counts_clean)
f.write(word_counts_clean)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-57dcbf205ca1> in <module>
#       1 f=open('f1.txt','w')
#       2 #s1='\n'.join(word_counts_clean)
# ----> 3 f.write(word_counts_clean)
#       4 f.close()
#
# TypeError: write() argument must be str, not list

# %%
palavras = pd.DataFrame(word_counts_clean, columns= ['frequencia', 'palavra'])

# %%
palavras.to_csv('palavras.csv', index = False)
